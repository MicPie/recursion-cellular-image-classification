# %% [markdown]
# # Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd

from fastai.vision import *
from fastai.vision.models.xresnet import *

# for datablock API
from fastai.vision.image import _resolve_tfms, _get_crop_target, _round_multiple, _get_resize_target, _affine_grid, _grid_sample, _affine_mult

# for XResNet
from fastai.vision.models.xresnet import act_fn, init_cnn, conv, noop, conv_layer, ResBlock, filt_sz

# %%
from nb_new_data_augmentation import *

# %%
import pdb

# %%
__version__
# Out:
# '1.0.55'

# %% [markdown]
# # 6D image test

# %%
class Image6D(Image):
    "Support applying transforms to image data in `px`."
    def __init__(self, px:Tensor):
        self._px = px
        self._logit_px=None
        self._flow=None
        self._affine_mat=None
        self.sample_kwargs = {}

    def _repr_image_format(self, format_str):
        with BytesIO() as str_buffer:
            #plt.imsave(str_buffer, image2np(self.px[:3]), format=format_str)
            plt.imsave(str_buffer, 
                       np.concatenate((image2np(self.px[:3]), 
                                       image2np(self.px[3:])), axis=1),
                       format=format_str)
            return str_buffer.getvalue()

# %%
def open_image_6D(fn:PathOrStr, div:bool=True, convert_mode:str='L', cls:type=Image6D,
        after_open:Callable=None)->Image:
    "Return `Image` object created from image in file `fn`."
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
        
        x = []
        for i in range(6):
            c = PIL.Image.open(fn+'_w'+str(i+1)+'.png').convert(convert_mode)
            if after_open: c = after_open(c)
            c = np.asarray(c)
            c = torch.from_numpy(c.astype(np.float32, copy=False))
            x.append(c)
            
    x = torch.stack(x)
    if div: x.div_(255)
    return cls(x)

# %%
#PATH_trunc = 'train/HEPG2-01/Plate1/B02_s1' # path is missing suffix "_w1.png"
#open_image_6D(PATH_trunc)

# %% [markdown]
# # Dataset setup

# %%
class ImageList6D(ImageList): #ImageList
    def __init__(self, *args, convert_mode='L', after_open:Callable=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.convert_mode,self.after_open = convert_mode,after_open
        self.copy_new.append('convert_mode')
        self.c,self.sizes = 6,{}
        
    def open(self, fn):
        "Open image in `fn`, subclass and overwrite for custom behavior."
        return open_image_6D(fn, convert_mode=self.convert_mode, after_open=self.after_open)

#    def show(self, img):
#        #return torch.cat((img[i][:3], img[i][3:]), dim=1)
#        show_image(img)
    
    # https://docs.fast.ai/tutorial.itemlist.html#Advanced-show-methods
    def show_xys(self, xs, ys, figsize:Tuple[int,int]=(15,10), **kwargs):
        "Show the `xs` and `ys` on a figure of `figsize`. `kwargs` are passed to the show method."
        rows = int(math.sqrt(len(xs)))
        fig, axs = plt.subplots(rows,rows,figsize=figsize)
        for i, ax in enumerate(axs.flatten() if rows > 1 else [axs]):
            #xs[i].show(ax=ax, y=ys[i], **kwargs)
            img = Image6D(torch.cat((xs[i].data[:3], xs[i].data[3:]), dim=2)) # works but not elegant?
            #img = Image6D(xs[i]) # does not work?
            img.show(ax=ax, y=ys[i], **kwargs)
        plt.tight_layout()

# %%
#def show_image(img:Image, ax:plt.Axes=None, figsize:tuple=(3,3), hide_axis:bool=True, cmap:str='binary',
#                alpha:float=None, **kwargs)->plt.Axes:
#    "Display `Image` in notebook."
#    if ax is None: fig,ax = plt.subplots(figsize=figsize)
#    pdb.set_trace()
#    #ax.imshow(image2np(img.data), cmap=cmap, alpha=alpha, **kwargs)
#    ax.imshow(np.concatenate((image2np(self.px[:3]),
#                              image2np(self.px[3:])), axis=1),
#              cmap=cmap, alpha=alpha, **kwargs)
#    if hide_axis: ax.axis('off')
#    return ax

# %% [markdown]
# ## Full dataset

# %% [markdown]
# ### Dataset parameters full dataset

# %%
df_train = pd.read_csv('full_train_dataset_valid-split-ex_v1_20190714.csv', index_col=0)
df_test = pd.read_csv('full_test_dataset_v1_20190714.csv', index_col=0)

# %%
df_train.head()
# Out:
#                      path experiment  sirna          multi  valid
# 0  HEPG2-01/Plate1/B03_s1   HEPG2-01    513   HEPG2-01 513      0
# 1  HEPG2-01/Plate1/B04_s1   HEPG2-01    840   HEPG2-01 840      0
# 2  HEPG2-01/Plate1/B05_s1   HEPG2-01   1020  HEPG2-01 1020      0
# 3  HEPG2-01/Plate1/B06_s1   HEPG2-01    254   HEPG2-01 254      0
# 4  HEPG2-01/Plate1/B07_s1   HEPG2-01    144   HEPG2-01 144      0

# %%
df_test.head()
# Out:
#                      path experiment
# 0  HEPG2-08/Plate1/B03_s1   HEPG2-08
# 1  HEPG2-08/Plate1/B04_s1   HEPG2-08
# 2  HEPG2-08/Plate1/B05_s1   HEPG2-08
# 3  HEPG2-08/Plate1/B06_s1   HEPG2-08
# 4  HEPG2-08/Plate1/B07_s1   HEPG2-08

# %% [markdown]
# ### Color augmentation transformation

# %% [markdown]
# "Color Augmentation: Color variability can be increased by applying random color transformations to original training samples. We perform color augmentation by transforming every color channels Ic ← ac · Ic + bc, where ac and bc are drawn from uniform distributions ac ∼ U [0.9, 1.1] and bc ∼ U [−10, +10]." from Domain-adversarial neural networks to address the appearance variability of histopathology images

# %%
# from https://github.com/fastai/fastai/blob/master/fastai/vision/transform.py#L137
#def _rgb_randomize(x, channel:int=None, thresh:float=0.3):
#    "Randomize one of the channels of the input image"
#    if channel is None: channel = np.random.randint(0, x.shape[0] - 1)
#    x[channel] = torch.rand(x.shape[1:]) * np.random.uniform(0, thresh)
#    return x
#
#rgb_randomize = TfmPixel(_rgb_randomize)

# %%
# Scaling factor comes from byte tensor?
#10/255 = 0.0392156862745098

# %%
def _color_augmentation(x):
    "Randomize all channels of the input image"
    channel_count = x.shape[0] - 1
    
    # by transforming every color channels Ic ← ac · Ic + bc, 
    # where ac and bc are drawn from uniform distributions 
    # ac ∼ U [0.9, 1.1] and 
    # bc ∼ U [−10, +10].
    
    # x [0,1]
    
    for c in range(channel_count):
        #pdb.set_trace()
        #print(x.min(), x.max())
        ac = np.random.uniform(0.9, 1.1) #np.random.uniform(0.9, 1.1)
        bc = np.random.uniform(-0.1,0.1) #np.random.uniform(-10, 10)
        x[c] = x[c] * ac + bc
        
        # clipping to min 0 and max 1
        x[c] = torch.clamp(x[c], 0., 1.)
    
    return x

color_augmentation = TfmPixel(_color_augmentation)

# %% [markdown]
# ### Transforms setup

# %%
## ResNet50pt
#sz, bs = 96, 8*46 # 77560MiB /  7952MiB

## XResNet50c
#sz, bs = 96, 8*46 # 7573MiB /  7952MiB
#sz, bs = 128, 8*52 # 7935MiB /  7952MiB
#sz, bs = 256, 8*13 # 7929MiB /  7952MiB
#sz, bs = 512, 8*3 # 7575MiB /  7952MiB

## XResNet50c AdaCos
#sz, bs = 128, 8*50 # 7846MiB /  7952MiB

## XResNet152fh
#sz, bs = 128, 8*23 # 7919MiB /  7952MiB

## SE_XResNet152fh
#sz, bs = 128, 8*18 # 7752MiB /  7952MiB
#sz, bs = 256, 8*4 # 7639MiB /  7952MiB
#sz, bs = 512, 8 #


## AdaCos-SE-XResNet50c FP32
#sz, bs = 128, 8 # TEST
#sz, bs = 128, 8*20 # 7430MiB /  7952MiB --> FP32 !!!
#sz, bs = 256, 8*5 # 7475MiB /  7952MiB
sz, bs = 512, 8 #
# === preds ===
#sz, bs = 256, 8*25 # 5391MiB /  7952MiB
#sz, bs = 256, 8*40 # 7741MiB /  7952MiB

# %%
sz, bs
# Out:
# (512, 8)

# %%
# normal tfms
#tfms = get_transforms()

# extended tfms
tfms = get_transforms(do_flip=True, flip_vert=True, 
                      max_rotate=90.0, max_zoom=1.1, 
                      max_lighting=0.2, max_warp=0.2, 
                      p_affine=0.75, p_lighting=0.75, 
                      xtra_tfms=color_augmentation())

# %%
# future transform mix?

# %% [markdown]
# ### Full dataset

# %%
data = (ImageList6D.from_df(df_train, path='train')
        .split_from_df(col=-1) # split_by_rand_pct()
        .label_from_df(cols=-3) # label_delim=' ' for MultiCategoryList !
        .add_test(ImageList6D.from_df(df_test, path='test'))
        .transform(tfms, size=sz) # .transform(size=sz)
        .databunch(bs=bs))

# %%
# PREDICTION
data = (ImageList6D.from_df(df_train, path='train')
        .split_from_df(col=-1) # split_by_rand_pct()
        .label_from_df(cols=-3) # label_delim=' ' for MultiCategoryList !
        .add_test(ImageList6D.from_df(df_test, path='test'))
        .transform(size=sz) # !!!
        .databunch(bs=bs))

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (28777 items)
# x: ImageList6D
# Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512)
# y: CategoryList
# 513,840,1020,254,144
# Path: train;
#
# Valid: LabelList (7738 items)
# x: ImageList6D
# Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512)
# y: CategoryList
# 352,361,503,505,70
# Path: train;
#
# Test: LabelList (19897 items)
# x: ImageList6D
# Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512),Image6D (6, 512, 512)
# y: EmptyLabelList
# ,,,,
# Path: train

# %%
data.c, len(data.classes), data.classes[-5:]
# Out:
# (1108, 1108, [1103, 1104, 1105, 1106, 1107])

# %%
data.train_ds[0]
# Out:
# (Image6D (6, 128, 128), Category 513)

# %%
#data.classes

# %%
data.train_ds[0][1], data.train_ds[0][1].data
# Out:
# (Category 513, 513)

# %%
data.train_ds[0][0]
# Out:
# Image6D (6, 256, 256)

# %%
data.test_ds[0][0]
# Out:
# Image6D (6, 256, 256)

# %% [markdown]
# ### Adversarial full dataset

# %%
data_a = (ImageList6D.from_df(df_train, path='train') # SET CORRECT DF!!!
        .split_from_df(col=-1) # split_by_rand_pct()
        .label_from_df(cols=-2, label_delim=' ') # label_delim=' ' for MultiCategoryList !
        .add_test(ImageList6D.from_df(df_train, path='train'))
        .transform(tfms, size=sz) # .transform(size=sz)
        .databunch(bs=bs))

# %%
data_a
# Out:
# ImageDataBunch;
#
# Train: LabelList (33191 items)
# x: ImageList6D
# Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128)
# y: MultiCategoryList
# HEPG2-01;513,HEPG2-01;840,HEPG2-01;1020,HEPG2-01;254,HEPG2-01;144
# Path: train;
#
# Valid: LabelList (3324 items)
# x: ImageList6D
# Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128),Image6D (6, 128, 128)
# y: MultiCategoryList
# 267,768,632,86,1051
# Path: train;
#
# Test: None

# %%
data_a.c, len(data_a.classes), data_a.classes[-5:]
# Out:
# (1138, 1138, ['RPE-03', 'RPE-04', 'RPE-05', 'RPE-06', 'RPE-07'])

# %%
data_a.batch_size
# Out:
# 208

# %%
data_a.train_ds[0]
# Out:
# (Image6D (6, 128, 128), MultiCategory HEPG2-01;513)

# %%
#data_a.classes

# %%
data_a.train_ds[0][1], data_a.train_ds[0][1].data
# Out:
# (MultiCategory HEPG2-01;513,
#  array([0., 0., 0., 0., ..., 0., 0., 0., 0.], dtype=float32))

# %%
data_a.train_ds[0][1].data.sum()
# Out:
# 2.0

# %%
np.where(data_a.train_ds[0][1].data > 0.5)
# Out:
# (array([ 569, 1108]),)

# %%
[data_a.classes[j] for j in np.where(data_a.train_ds[0][1].data > 0.5)[0]]
# Out:
# ['513', 'HEPG2-01']

# %%
data_a.train_ds[0][0]
# Out:
# Image6D (6, 128, 128)

# %%
# DOES NOT WORK?
#data_a.train_ds[0][0].show()

# %% [markdown]
# # Model setup

# %% [markdown]
# ## SE-XResNet50Feature+AdaCos-Head

# %% [markdown]
# SE-XResNet152Feature model including AdaptiveConcatPool2d stage + normal fastai head

# %%
# Check regularly for improvments: https://github.com/fastai/fastai_dev/blob/master/dev/60_vision_models_xresnet.ipynb

# %%
# from https://github.com/Cadene/pretrained-models.pytorch/blob/master/pretrainedmodels/models/senet.py#L85
class SE_Module(Module): # change nn.Module to Module

    def __init__(self, channels, reduction=16):
        #super(SE_Module, self).__init__() # not needed?
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1,
                             padding=0)
        self.relu = nn.ReLU(inplace=True)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1,
                             padding=0)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        module_input = x
        x = self.avg_pool(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return module_input * x

# %%
# fastai resblock combined with SEModule
class SE_ResBlock(Module):
    def __init__(self, expansion, ni, nh, stride=1):
        nf,ni = nh*expansion,ni*expansion
        layers  = [conv_layer(ni, nh, 3, stride=stride),
                   conv_layer(nh, nf, 3, zero_bn=True, act=False)
        ] if expansion == 1 else [
                   conv_layer(ni, nh, 1),
                   conv_layer(nh, nh, 3, stride=stride),
                   conv_layer(nh, nf, 1, zero_bn=True, act=False)
        ]
        #self.convs = nn.Sequential(*layers) # without SEModule
        self.convs = nn.Sequential(*layers, SE_Module(nf))
        # TODO: check whether act=True works better
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act=False)
        self.pool = noop if stride==1 else nn.AvgPool2d(2, ceil_mode=True)

    def forward(self, x): return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# %%
class SE_XResNetFeature(nn.Sequential):
    def __init__(self, expansion, layers, c_in=6):#, c_out=1108):
        stem = []
        sizes = [c_in,32,32,64]
        for i in range(3):
            stem.append(conv_layer(sizes[i], sizes[i+1], stride=2 if i==0 else 1))
            #nf = filt_sz(c_in*9)
            #stem.append(conv_layer(c_in, nf, stride=2 if i==1 else 1))
            #c_in = nf

        block_szs = [64//expansion,64,128,256,512]
        blocks = [self._make_layer(expansion, block_szs[i], block_szs[i+1], l, 1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        super().__init__(
            *stem,
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            *blocks,
            #AdaptiveConcatPool2d(), Flatten(),
            #nn.AdaptiveAvgPool2d(1), Flatten(),
            # remove head:
            #nn.Linear(block_szs[-1]*expansion, c_out)
        )
        init_cnn(self)

    def _make_layer(self, expansion, ni, nf, blocks, stride):
        return nn.Sequential(
            *[SE_ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
              for i in range(blocks)])

# %%
#se_xresnet152f = SE_XResNetFeature(4, [3,8,36,3], c_in=6) #, c_out=1108)
se_xresnet50f = SE_XResNetFeature(4, [3,4,6 ,3], c_in=6) #, c_out=1108)

# %%
#se_xresnet152f

# %%
#se_xresnet50f(torch.randn(1,6,sz,sz)).shape

# %%
#se_xresnet50f(data.train_ds[0][0].data.unsqueeze(0)).shape

# %% [markdown]
# ### AdaCos-Head

# %%
def create_adacos_head(nf:int, lin_ftrs:Optional[Collection[int]]=None, ps:Floats=0.5,
                concat_pool:bool=True, bn_final:bool=False):
    #nc:int, 
    "Model head that takes `nf` features, runs through `lin_ftrs`, and about `nc` classes."
    lin_ftrs = [nf, 512, 512] if lin_ftrs is None else [nf] + lin_ftrs + [nc]
    ps = listify(ps)
    if len(ps) == 1: ps = [ps[0]/2] * (len(lin_ftrs)-2) + ps
    actns = [nn.ReLU(inplace=True)] * (len(lin_ftrs)-2) + [None]
    pool = AdaptiveConcatPool2d() if concat_pool else nn.AdaptiveAvgPool2d(1)
    layers = [pool, Flatten()]
    for ni,no,p,actn in zip(lin_ftrs[:-1], lin_ftrs[1:], ps, actns):
        layers += bn_drop_lin(ni, no, True, p, actn)
    if bn_final: layers.append(nn.BatchNorm1d(lin_ftrs[-1], momentum=0.01))
    #layers.append(AdaCos(lin_ftrs[-1], nc))
    return nn.Sequential(*layers)

# %%
adacos_head = create_adacos_head(nf=4*512*2)#, nc=1108)

# %%
#adacos_head

# %%
#adacos_head(torch.randn(2, 2048, 4, 4)).shape

# %%
# from https://github.com/4uiiurz1/pytorch-adacos/blob/master/metrics.py
class AdaCos(nn.Module):
    def __init__(self, num_features, num_classes, m=0.50):
        super(AdaCos, self).__init__()
        self.num_features = num_features
        self.n_classes = num_classes
        self.s = math.sqrt(2) * math.log(num_classes - 1)
        self.m = m
        self.W = nn.Parameter(torch.FloatTensor(num_classes, num_features))
        nn.init.xavier_uniform_(self.W)

    def forward(self, xb, yb):
        
        #print(yb.shape)
        #pdb.set_trace()
        
        # normalize features
        x = F.normalize(xb)
        # normalize weights
        W = F.normalize(self.W)
        # dot product
        logits = F.linear(x, W)
        
        #if yb is None:
        #    return logits
        
        # feature re-scale
        theta = torch.acos(torch.clamp(logits, -1.0 + 1e-7, 1.0 - 1e-7))
        one_hot = torch.zeros_like(logits)
        
        #one_hot.scatter_(1, yb.view(-1, 1).long(), 1)
        #one_hot.scatter_(1, torch.tensor(yb).view(-1,1).long(), 1)
        one_hot.scatter_(1, yb.view(-1,1).long(), 1)
        
        with torch.no_grad():
            B_avg = torch.where(one_hot < 1, torch.exp(self.s * logits), torch.zeros_like(logits))
            B_avg = torch.sum(B_avg) / xb.size(0)
            #print(B_avg)
            theta_med = torch.median(theta[one_hot == 1])
            self.s = torch.log(B_avg) / torch.cos(torch.min(math.pi/4 * torch.ones_like(theta_med), theta_med))
            #print(self.s)
        output = self.s * logits

        return output

# %%
class AdaCosNet(nn.Module):
    '''Simple AdaCosNet connecter to run xb through the feature extractor head
    and then feed xb and yb into the AdaCos layer.'''
    def __init__(self, body, head):
        super(AdaCosNet, self).__init__()
        self.body = body
        self.head = head
        self.adacos = AdaCos(512, 1108)
        
    def forward(self, xb, yb):
        features = self.body(xb)
        out = self.head(features)
        #print('xb.shape: ', xb.shape,', yb.shape: ', yb.shape)
        out = self.adacos(out, yb)
        #print('out: ',out.shape)
        #pdb.set_trace()
        return out

# %%
adacos_se_xresnet50c = AdaCosNet(se_xresnet50f, adacos_head)

# %%
adacos_se_xresnet50c(torch.randn(2,6,sz,sz), torch.tensor([513, 1])).shape
# Out:
# torch.Size([2, 1108])

# %%
#xb, yb = next(iter(data.train_dl))

# %%
#xb.shape, yb.shape

# %%
#adacos_se_xresnet50c.cuda();

# %%
#adacos_se_xresnet50c(xb,yb).shape

# %%
#adacos_se_xresnet50c(xb,yb)

# %%
# Based on https://forums.fast.ai/t/teacher-forcing/29415/4
# https://forums.fast.ai/t/on-batch-begin-callback/35201/3
@dataclass
class AppendBatchTargs(Callback):
    learn:Learner
    def __init__(self, learn):
        super().__init__()
    def on_batch_begin(self, last_input, last_target, **kwargs):
        return {'last_input':(last_input, last_target), 'last_target':last_target}

# %%
#@dataclass
#class AppendBatchTargs(LearnerCallback):
#    def __init__(self, learn:Learner):
#        super().__init__()
#    def on_batch_begin(self, last_input, last_target, **kwargs):
#        return {'last_input':(last_input, last_target), 'last_target':last_target}

# %% [markdown]
# # Training

# %% [markdown]
# ## adacos_se_xresnet50c

# %%
from fastai.callbacks import CSVLogger, ReduceLROnPlateauCallback, SaveModelCallback

# %%
learn = Learner(data, adacos_se_xresnet50c, metrics=[accuracy], callback_fns=[CSVLogger, AppendBatchTargs])#.to_fp16()

# %%
#learn.opt_func

# %%
# Make Adam FP16 proof:
# https://forums.fast.ai/t/mixed-precision-training/29601/21
# https://discuss.pytorch.org/t/adam-half-precision-nans/1765
# https://vxlabs.com/2019/02/04/improving-fastais-mixed-precision-support-with-nvidias-automatic-mixed-precision/
#learn.opt_func = partial(learn.opt_func, eps=1e-4)
#learn.opt_func

### ADD CLIP PARAMETER TOO???

# %%
learn.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %% [markdown]
# ### 128px Standard training

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.63E-05
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(4, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.104717</td>
#       <td>7.055364</td>
#       <td>0.001809</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.024161</td>
#       <td>6.977803</td>
#       <td>0.003231</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.871113</td>
#       <td>6.828512</td>
#       <td>0.003231</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.751935</td>
#       <td>6.826463</td>
#       <td>0.004652</td>
#       <td>03:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.recorder.plot_lr(show_moms=True)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.32E-07

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.729484</td>
#       <td>6.784797</td>
#       <td>0.004652</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.802896</td>
#       <td>6.880405</td>
#       <td>0.003489</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.735397</td>
#       <td>6.867959</td>
#       <td>0.003360</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.625309</td>
#       <td>6.791791</td>
#       <td>0.004006</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.497015</td>
#       <td>6.678201</td>
#       <td>0.005299</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.349478</td>
#       <td>6.633062</td>
#       <td>0.007495</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.224877</td>
#       <td>6.564163</td>
#       <td>0.008788</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6.138471</td>
#       <td>6.545199</td>
#       <td>0.008271</td>
#       <td>03:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-05
# Min loss divided by 10: 5.75E-05

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.173625</td>
#       <td>6.620019</td>
#       <td>0.008142</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.280900</td>
#       <td>6.672861</td>
#       <td>0.006462</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.257083</td>
#       <td>6.557673</td>
#       <td>0.009563</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.130602</td>
#       <td>6.477049</td>
#       <td>0.011760</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.995426</td>
#       <td>6.422742</td>
#       <td>0.011502</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.842599</td>
#       <td>6.310201</td>
#       <td>0.015379</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.704380</td>
#       <td>6.266299</td>
#       <td>0.017059</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.611087</td>
#       <td>6.268888</td>
#       <td>0.017446</td>
#       <td>03:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e020_20190723', return_path=True)
# Out:
# PosixPath('train/models/resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e020_20190723.pth')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e020_20190723');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.09E-05
# Min loss divided by 10: 5.75E-05

# %%
learn.fit_one_cycle(20, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [12/20 37:18<24:52]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.615267</td>
#       <td>6.249466</td>
#       <td>0.018609</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.635270</td>
#       <td>6.259812</td>
#       <td>0.017446</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.682876</td>
#       <td>6.435584</td>
#       <td>0.011760</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.731081</td>
#       <td>6.407343</td>
#       <td>0.015896</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.739407</td>
#       <td>6.399476</td>
#       <td>0.013828</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.699776</td>
#       <td>6.315452</td>
#       <td>0.018480</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.613810</td>
#       <td>6.392146</td>
#       <td>0.019773</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.545374</td>
#       <td>6.064626</td>
#       <td>0.024554</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>5.446128</td>
#       <td>5.991362</td>
#       <td>0.027526</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>5.344337</td>
#       <td>5.897239</td>
#       <td>0.034893</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.236681</td>
#       <td>5.852475</td>
#       <td>0.033600</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>5.143377</td>
#       <td>5.805990</td>
#       <td>0.043422</td>
#       <td>03:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='32' class='' max='49', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       65.31% [32/49 00:26<00:14]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e040_20190723', return_path=True)
# Out:
# PosixPath('train/models/resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e040_20190723.pth')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e040_20190723');

# %% [markdown]
# ### 128px over night

# %%
redlr = ReduceLROnPlateauCallback(learn, monitor='valid_loss', patience=8)
savem = SaveModelCallback(learn, every='improvement', monitor='accuracy', 
                          name='resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e040-200_20190723_best')

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.20E-05
# Min loss divided by 10: 3.98E-07

# %%
learn.fit(160, lr=1e-3, callbacks=[savem, redlr])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='103' class='' max='160', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       64.38% [103/160 5:22:13<2:58:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.032759</td>
#       <td>5.655125</td>
#       <td>0.047428</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.970773</td>
#       <td>5.940760</td>
#       <td>0.035151</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.941909</td>
#       <td>5.650648</td>
#       <td>0.048204</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.878484</td>
#       <td>5.580300</td>
#       <td>0.057508</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.834744</td>
#       <td>5.755776</td>
#       <td>0.044973</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.808781</td>
#       <td>5.518294</td>
#       <td>0.061515</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.752865</td>
#       <td>5.476137</td>
#       <td>0.062807</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.707845</td>
#       <td>5.477857</td>
#       <td>0.071078</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.661770</td>
#       <td>5.432075</td>
#       <td>0.063970</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.611949</td>
#       <td>5.503659</td>
#       <td>0.064616</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.571412</td>
#       <td>5.504735</td>
#       <td>0.061515</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>4.534949</td>
#       <td>5.434233</td>
#       <td>0.069010</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.473216</td>
#       <td>5.363117</td>
#       <td>0.075342</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>4.463261</td>
#       <td>5.211245</td>
#       <td>0.083355</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>4.409620</td>
#       <td>5.390213</td>
#       <td>0.072758</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4.376091</td>
#       <td>5.313982</td>
#       <td>0.077669</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>4.335268</td>
#       <td>5.237312</td>
#       <td>0.081546</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.295721</td>
#       <td>5.140745</td>
#       <td>0.089041</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>4.240744</td>
#       <td>5.078681</td>
#       <td>0.097312</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>4.227730</td>
#       <td>5.150939</td>
#       <td>0.087749</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.211778</td>
#       <td>4.972561</td>
#       <td>0.103515</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>4.170346</td>
#       <td>5.071489</td>
#       <td>0.100284</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.136152</td>
#       <td>4.974212</td>
#       <td>0.108814</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>4.100831</td>
#       <td>5.044335</td>
#       <td>0.098734</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>4.081366</td>
#       <td>4.995252</td>
#       <td>0.099638</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>4.047506</td>
#       <td>4.912824</td>
#       <td>0.109201</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.996085</td>
#       <td>4.890368</td>
#       <td>0.118894</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.984353</td>
#       <td>4.990249</td>
#       <td>0.103903</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>3.950622</td>
#       <td>4.887682</td>
#       <td>0.122383</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.907143</td>
#       <td>4.876653</td>
#       <td>0.117085</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>3.878666</td>
#       <td>5.033703</td>
#       <td>0.107909</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>3.876627</td>
#       <td>5.096468</td>
#       <td>0.097441</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>3.846723</td>
#       <td>4.958015</td>
#       <td>0.109589</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>3.799156</td>
#       <td>4.908925</td>
#       <td>0.116438</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.791360</td>
#       <td>5.174811</td>
#       <td>0.091109</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>3.725492</td>
#       <td>4.807248</td>
#       <td>0.127294</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>3.711209</td>
#       <td>4.810761</td>
#       <td>0.132075</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>3.667763</td>
#       <td>4.903225</td>
#       <td>0.122383</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>3.663852</td>
#       <td>4.769090</td>
#       <td>0.126906</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>3.628148</td>
#       <td>4.825680</td>
#       <td>0.127294</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>3.606246</td>
#       <td>4.769296</td>
#       <td>0.131817</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>3.562754</td>
#       <td>4.806225</td>
#       <td>0.129362</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>3.548708</td>
#       <td>4.755229</td>
#       <td>0.131946</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>3.516511</td>
#       <td>4.731421</td>
#       <td>0.136469</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>3.474502</td>
#       <td>4.799628</td>
#       <td>0.131429</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>3.467281</td>
#       <td>5.056339</td>
#       <td>0.114112</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>3.442369</td>
#       <td>4.764025</td>
#       <td>0.133626</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>3.411897</td>
#       <td>4.808250</td>
#       <td>0.129620</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.374613</td>
#       <td>4.871289</td>
#       <td>0.128586</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>3.351413</td>
#       <td>4.799424</td>
#       <td>0.131300</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.348739</td>
#       <td>4.781643</td>
#       <td>0.142414</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>3.281031</td>
#       <td>4.734165</td>
#       <td>0.140605</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.264352</td>
#       <td>4.909501</td>
#       <td>0.126131</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.962077</td>
#       <td>4.626870</td>
#       <td>0.151460</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.889388</td>
#       <td>4.549742</td>
#       <td
# Better model found at epoch 0 with accuracy value: 0.047428276389837265.
# Better model found at epoch 2 with accuracy value: 0.04820366948843002.
# Better model found at epoch 3 with accuracy value: 0.057508401572704315.
# Better model found at epoch 5 with accuracy value: 0.06151460483670235.
# Better model found at epoch 6 with accuracy value: 0.06280692666769028.
# Better model found at epoch 7 with accuracy value: 0.07107780128717422.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Better model found at epoch 50 with accuracy value: 0.14241406321525574.
# Epoch 52: reducing lr to 0.0002
# Better model found at epoch 53 with accuracy value: 0.15146031975746155.
# Better model found at epoch 54 with accuracy value: 0.163091242313385.
# Epoch 99: reducing lr to 6.400000000000003e-08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-6ce6b8c5c75e> in <module>
# ----> 1 learn.fit(160, lr=1e-3, callbacks=[savem, redlr])
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     199         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
# ---> 35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/callback.py in step(self)
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      56             self.set_val('weight_decay', listify(0, self._wd))
# ---> 57         self.opt.step()
#      58
#      59     def zero_grad(self)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      91
#      92                 # Decay the first and second moment running average coefficient
# ---> 93                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      94                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      95                 if amsgrad:
#
# KeyboardInterrupt:

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
# Best model save as "adacos_se_xresnet50c_val-split-ex-v1_128px_e040-143_20190723_best"!

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e143_20190723', return_path=True)
# Out:
# PosixPath('train/models/resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e143_20190723.pth')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128px_e143_20190723');

# %% [markdown]
# ### 256px Standard training

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.00E-03
# Min loss divided by 10: 5.25E-04

# %%
learn.fit_one_cycle(4, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.947112</td>
#       <td>4.962834</td>
#       <td>0.112432</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.965914</td>
#       <td>4.733676</td>
#       <td>0.140088</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.554372</td>
#       <td>4.509617</td>
#       <td>0.175239</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.232993</td>
#       <td>4.399100</td>
#       <td>0.186482</td>
#       <td>05:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
#learn.recorder.plot_lr(show_moms=True)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.10E-06
# Min loss divided by 10: 2.75E-07

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.293216</td>
#       <td>4.476551</td>
#       <td>0.180408</td>
#       <td>05:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.820862</td>
#       <td>4.746135</td>
#       <td>0.144482</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.869327</td>
#       <td>4.608175</td>
#       <td>0.161411</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.849073</td>
#       <td>4.820482</td>
#       <td>0.136469</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.603731</td>
#       <td>4.532677</td>
#       <td>0.166322</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.370605</td>
#       <td>4.449434</td>
#       <td>0.192427</td>
#       <td>05:42</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.074850</td>
#       <td>4.353207</td>
#       <td>0.203670</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.959158</td>
#       <td>4.324511</td>
#       <td>0.205221</td>
#       <td>05:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e012_20190724', return_path=True)
# Out:
# PosixPath('train/models/resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e012_20190724.pth')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e012_20190724');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-07
# Min loss divided by 10: 1.10E-07

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.118327</td>
#       <td>4.424854</td>
#       <td>0.195399</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.534343</td>
#       <td>4.654649</td>
#       <td>0.165934</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.694319</td>
#       <td>4.696074</td>
#       <td>0.156242</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.585044</td>
#       <td>4.729616</td>
#       <td>0.149522</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.336039</td>
#       <td>4.472053</td>
#       <td>0.185578</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.078976</td>
#       <td>4.320912</td>
#       <td>0.212458</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.847661</td>
#       <td>4.261994</td>
#       <td>0.219049</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.802058</td>
#       <td>4.266299</td>
#       <td>0.218532</td>
#       <td>05:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256px_e020_20190724')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256px_e020_20190724');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 1.32E-07

# %%
learn.fit_one_cycle(20, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [16/20 1:31:56<22:59]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.776855</td>
#       <td>4.234746</td>
#       <td>0.223314</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.865056</td>
#       <td>4.347148</td>
#       <td>0.208323</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.041264</td>
#       <td>4.471642</td>
#       <td>0.186353</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.196819</td>
#       <td>4.542531</td>
#       <td>0.182735</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.362502</td>
#       <td>4.501162</td>
#       <td>0.183251</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.442168</td>
#       <td>4.785266</td>
#       <td>0.151977</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.413276</td>
#       <td>4.696085</td>
#       <td>0.149522</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.348523</td>
#       <td>4.578371</td>
#       <td>0.168648</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.296484</td>
#       <td>4.565764</td>
#       <td>0.170587</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.184754</td>
#       <td>4.607510</td>
#       <td>0.171362</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.064049</td>
#       <td>4.365025</td>
#       <td>0.203153</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.983769</td>
#       <td>4.477338</td>
#       <td>0.193461</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.802685</td>
#       <td>4.325958</td>
#       <td>0.211941</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.674404</td>
#       <td>4.336636</td>
#       <td>0.210261</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.488444</td>
#       <td>4.283871</td>
#       <td>0.225510</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.349070</td>
#       <td>4.237583</td>
#       <td>0.226544</td>
#       <td>05:45</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='532' class='' max='719', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.99% [532/719 03:43<01:18 2.2586]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256px_e040_20190724')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256px_e040_20190724');

# %% [markdown]
# ### 256px over day

# %%
redlr = ReduceLROnPlateauCallback(learn, monitor='accuracy', patience=8)
savem = SaveModelCallback(learn, every='improvement', monitor='accuracy', 
                          name='resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e040-140_20190724_best')

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.10E-07

# %%
learn.fit(100, lr=1e-3, callbacks=[savem, redlr])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       88.00% [88/100 8:25:29<1:08:55]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.957059</td>
#       <td>4.665542</td>
#       <td>0.168261</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.943757</td>
#       <td>4.619302</td>
#       <td>0.170199</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.990883</td>
#       <td>4.536920</td>
#       <td>0.180150</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.917122</td>
#       <td>4.559470</td>
#       <td>0.185965</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.853210</td>
#       <td>4.625964</td>
#       <td>0.169941</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.838643</td>
#       <td>4.641917</td>
#       <td>0.173688</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.699526</td>
#       <td>4.583181</td>
#       <td>0.183122</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.735897</td>
#       <td>4.571822</td>
#       <td>0.178082</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.765952</td>
#       <td>4.537967</td>
#       <td>0.178987</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.690423</td>
#       <td>4.514685</td>
#       <td>0.190618</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.628617</td>
#       <td>4.496306</td>
#       <td>0.197726</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.588160</td>
#       <td>4.402676</td>
#       <td>0.197984</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.510579</td>
#       <td>4.541017</td>
#       <td>0.187258</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.433292</td>
#       <td>4.491480</td>
#       <td>0.196433</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.452330</td>
#       <td>4.597472</td>
#       <td>0.185190</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.337893</td>
#       <td>4.528752</td>
#       <td>0.191135</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.304396</td>
#       <td>4.582869</td>
#       <td>0.184027</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.270951</td>
#       <td>4.664172</td>
#       <td>0.176531</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.209574</td>
#       <td>4.552736</td>
#       <td>0.195787</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.168989</td>
#       <td>4.543596</td>
#       <td>0.196175</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.124383</td>
#       <td>4.678826</td>
#       <td>0.185965</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.531419</td>
#       <td>4.389584</td>
#       <td>0.225381</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.431025</td>
#       <td>4.382417</td>
#       <td>0.222926</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.378570</td>
#       <td>4.420694</td>
#       <td>0.220212</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.308505</td>
#       <td>4.435348</td>
#       <td>0.218532</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.261488</td>
#       <td>4.420065</td>
#       <td>0.222021</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.232331</td>
#       <td>4.458756</td>
#       <td>0.219824</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.242748</td>
#       <td>4.459792</td>
#       <td>0.220083</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.200487</td>
#       <td>4.469875</td>
#       <td>0.212846</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.144300</td>
#       <td>4.481629</td>
#       <td>0.217757</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.120626</td>
#       <td>4.485864</td>
#       <td>0.219307</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.037717</td>
#       <td>4.450077</td>
#       <td>0.221763</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.038490</td>
#       <td>4.473285</td>
#       <td>0.218403</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.028898</td>
#       <td>4.488717</td>
#       <td>0.219953</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.006348</td>
#       <td>4.483450</td>
#       <td>0.219695</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.016129</td>
#       <td>4.484622</td>
#       <td>0.219566</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.008390</td>
#       <td>4.483840</td>
#       <td>0.219695</td>
#       <td>05:42</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.005070</td>
#       <td>4.493301</td>
#       <td>0.220600</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.972278</td>
#       <td>4.469025</td>
#       <td>0.224347</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.990053</td>
#       <td>4.521721</td>
#       <td>0.218144</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.974339</td>
#       <td>4.485398</td>
#       <td>0.221375</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.967034</td>
#       <td>4.510666</td>
#       <td>0.218661</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.946223</td>
#       <td>4.505508</td>
#       <td>0.219307</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.961358</td>
#       <td>4.490207</td>
#       <td>0.219824</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.957027</td>
#       <td>4.502748</td>
#       <td>0.220858</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.949051</td>
#       <td>4.495834</td>
#       <td>0.219049</td>
#       <td>05:41</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.962353</td>
#       <td>4.505159</td>
#       <td>0.219695</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.952768</td>
#       <td>4.495187</td>
#       <td>0.220470</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.947574</td>
#       <td>4.491970</td>
#       <td>0.220341</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.954140</td>
#       <td>4.493429</td>
#       <td>0.220212</td>
#       <td>05:45</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.944856</td>
#       <td>4.502846</td>
#       <td>0.218403</td>
#       <td>05:43</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.966940</td>
#       <td>4.500113</td>
#       <td>0.219695</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.938098</td>
#       <td>4.490582</td>
#       <td>0.223572</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.972114</td>
#       <td>4.478227</td>
#       <td>0.220083</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.947834</td>
#       <td>4.522323</td>
#       <td>0
# Better model found at epoch 0 with accuracy value: 0.16826052963733673.
# Better model found at epoch 1 with accuracy value: 0.17019902169704437.
# Better model found at epoch 2 with accuracy value: 0.18014991283416748.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-347a61dfa4c6> in <module>
# ----> 1 learn.fit(100, lr=1e-3, callbacks=[savem, redlr])
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     199         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
# ---> 35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/callback.py in step(self)
#      51         if self.true_wd:
#      52             for lr,wd,pg1,pg2 in zip(self._lr,self._wd,self.opt.param_groups[::2],self.opt.param_groups[1::2]):
# ---> 53                 for p in pg1['params']: p.data.mul_(1 - wd*lr)
#      54                 if self.bn_wd:
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#
# KeyboardInterrupt:

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_20190724')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_20190724');

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e040-128_20190724_best')

# %% [markdown]
# ### 512px Standard training - DOES NOT WORK!

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 9.12E-08

# %%
learn.fit_one_cycle(4, max_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.652491</td>
#       <td>5.389850</td>
#       <td>0.089300</td>
#       <td>21:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.259241</td>
#       <td>5.315614</td>
#       <td>0.106875</td>
#       <td>21:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.634538</td>
#       <td>4.999095</td>
#       <td>0.160248</td>
#       <td>21:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.286586</td>
#       <td>4.927083</td>
#       <td>0.166581</td>
#       <td>21:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
#learn.recorder.plot_lr(show_moms=True)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 9.12E-08

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.50% [7/8 2:30:28<21:29]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.484501</td>
#       <td>5.023548</td>
#       <td>0.161024</td>
#       <td>21:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.224343</td>
#       <td>5.532135</td>
#       <td>0.094727</td>
#       <td>21:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.593681</td>
#       <td>5.611809</td>
#       <td>0.095632</td>
#       <td>21:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.541505</td>
#       <td>5.627266</td>
#       <td>0.104032</td>
#       <td>21:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.393831</td>
#       <td>5.583842</td>
#       <td>0.108814</td>
#       <td>21:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.157751</td>
#       <td>5.287598</td>
#       <td>0.157147</td>
#       <td>21:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.972212</td>
#       <td>5.212036</td>
#       <td>0.164642</td>
#       <td>21:28</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='217' class='' max='3597', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.03% [217/3597 01:12<18:55 4.7613]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e012_20190724')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e012_20190724');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.63E-05
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(8, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       87.50% [7/8 2:30:39<21:31]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.057042</td>
#       <td>5.307115</td>
#       <td>0.151073</td>
#       <td>21:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.355778</td>
#       <td>5.647734</td>
#       <td>0.102094</td>
#       <td>21:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.602813</td>
#       <td>5.678941</td>
#       <td>0.101318</td>
#       <td>21:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.523734</td>
#       <td>5.589343</td>
#       <td>0.095373</td>
#       <td>21:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.368180</td>
#       <td>5.442150</td>
#       <td>0.139054</td>
#       <td>21:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.212189</td>
#       <td>5.288412</td>
#       <td>0.172267</td>
#       <td>21:30</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.974287</td>
#       <td>5.212771</td>
#       <td>0.176014</td>
#       <td>21:31</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='182' class='' max='3597', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.06% [182/3597 01:01<19:14 4.8396]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e020_20190724')

# %% [markdown]
# #### Underflow?

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e020_20190724');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.58E-06
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(20, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       55.00% [11/20 3:47:28<3:06:06]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:41</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000905</td>
#       <td>20:40</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='3597', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-66ac1fbf9b12> in <module>
# ----> 1 learn.fit_one_cycle(20, max_lr=1e-3)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     199         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-37-a3d322728eb2> in forward(self, xb, yb)
#      12         out = self.head(features)
#      13         #print('xb.shape: ', xb.shape,', yb.shape: ', yb.shape)
# ---> 14         out = self.adacos(out, yb)
#      15         #print('out: ',out.shape)
#      16         #pdb.set_trace()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-36-fc1458ad217e> in forward(self, xb, yb)
#      37             B_avg = torch.sum(B_avg) / xb.size(0)
#      38             #print(B_avg)
# ---> 39             theta_med = torch.median(theta[one_hot == 1])
#      40             self.s = torch.log(B_avg) / torch.cos(torch.min(math.pi/4 * torch.ones_like(theta_med), theta_med))
#      41             #print(self.s)
#
# KeyboardInterrupt:

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %% [markdown]
# #### Retest

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e020_20190724');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.74E-03
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(4, max_lr=1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.00% [1/4 21:26<1:04:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.838001</td>
#       <td>5.230891</td>
#       <td>0.181313</td>
#       <td>21:26</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2095' class='' max='3597', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       58.24% [2095/3597 11:37<08:20 4.8333]
#     </div>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e024_20190725')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e024_20190725');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)

# %% [markdown]
# ### 512px over day

# %%
redlr = ReduceLROnPlateauCallback(learn, monitor='accuracy', patience=4)
savem = SaveModelCallback(learn, every='improvement', monitor='accuracy', 
                          name='resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e024-050_20190725_best')

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)

# %%
learn.fit(26, lr=1e-4, callbacks=[savem, redlr])

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e050_20190725')

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e050_20190725');

# %% [markdown]
# # Get features

# %%
learn = Learner(data, adacos_se_xresnet50c)

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e040-128_20190724_best');

# %%
def get_feats(model, dataloader):
    feats = []
    targs = []
    model.eval()
    with torch.no_grad():
        for xb, yb in dataloader:
            body_out = adacos_se_xresnet50c.body(xb)
            head_out = adacos_se_xresnet50c.head(body_out)
            feats.append(head_out.cpu())
            targs.append(yb.cpu())
    return feats, targs

# %% [markdown]
# ## Train

# %%
feats, targs = get_feats(learn.model, learn.data.train_dl)

# %%
len(feats), len(targs)
# Out:
# (89, 89)

# %%
# total images: 89*320
learn.data.batch_size * len(learn.data.train_dl)
# Out:
# 28480

# %%
#len(learn.data.train_dl), len(learn.data.valid_dl), len(learn.data.test_dl)

# %%
feats = torch.cat(feats, dim=0)
targs = torch.cat(targs, dim=0)

# %%
feats.shape, targs.shape
# Out:
# (torch.Size([28480, 512]), torch.Size([28480]))

# %%
np.save('feats_train.npy', feats)
np.save('targs_train.npy', targs)

# %% [markdown]
# ## Valid

# %%
feats, targs = get_feats(learn.model, learn.data.valid_dl)

# %%
len(feats), len(targs)
# Out:
# (25, 25)

# %%
feats = torch.cat(feats, dim=0)
targs = torch.cat(targs, dim=0)

# %%
feats.shape, targs.shape
# Out:
# (torch.Size([7738, 512]), torch.Size([7738]))

# %%
np.save('feats_valid.npy', feats)
np.save('targs_valid.npy', targs)

# %% [markdown]
# ## Test

# %%
feats, targs = get_feats(learn.model, learn.data.test_dl)

# %%
del targs

# %%
len(feats)
# Out:
# 19897

# %%
feats = torch.cat(feats, dim=0)

# %%
feats.shape
# Out:
# torch.Size([19897, 512])

# %%
np.save('feats_test.npy', feats)

# %% [markdown]
# # Submission

# %% [markdown]
# ## AdaCos

# %%
# get the names
preds_names = learn.data.test_ds.x.items

# %%
preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3][:3] for x in preds_names]
# including sX
#preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3] for x in preds_names]

# %%
len(preds_names)
# Out:
# 19897

# %%
preds_test = np.load('preds_test.npy')

# %%
preds_test
# Out:
# array([  18,  499,  525, 1043, ...,  316,  429,  271,  557])

# %%
df_preds = pd.DataFrame({'id_code': preds_names, 'sirna': preds_test})

# %%
df_preds.head()
# Out:
#           id_code  sirna
# 0  HEPG2-08_1_B03     18
# 1  HEPG2-08_1_B04    499
# 2  HEPG2-08_1_B05    525
# 3  HEPG2-08_1_B06   1043
# 4  HEPG2-08_1_B07    903

# %%
# 'resnet50/adacos_se_xresnet50c_val-split-ex-v1_128e143_256e040-128_20190724_best'
model = 'metriclearn_se_xresnet50c_val-split-ex-v1_128e143_256e040-128_20190724_best'

# %%
df_preds.to_csv('sub/'+model+'.csv.gz', index=False, compression='gzip')

# %%
# !kaggle competitions submit -c recursion-cellular-image-classification -f sub/{model}.csv.gz -m "{model}"
# Out:
# 100%|██████████████████████████████████████| 83.5k/83.5k [00:05<00:00, 16.4kB/s]
# Successfully submitted to Recursion Cellular Image Classification

# %% [markdown]
# ## Old - Get predicitions

# %%
model = 'metriclearn_se_xresnet50c_val-split-ex-v1_128e143_256e128_512e020_20190724'

# %%
#learn.load('resnet152/'+model)
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (28777 items)
# x: ImageList6D
# Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256)
# y: CategoryList
# 513,840,1020,254,144
# Path: train;
#
# Valid: LabelList (7738 items)
# x: ImageList6D
# Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256)
# y: CategoryList
# 352,361,503,505,70
# Path: train;
#
# Test: LabelList (19897 items)
# x: ImageList6D
# Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256),Image6D (6, 256, 256)
# y: EmptyLabelList
# ,,,,
# Path: train, model=Sequential(
#   (0): SE_XResNetFeature(
#     (0): Sequential(
#       (0): Conv2d(6, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#     )
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (idconv): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (2): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#     )
#     (5): Sequential(
#       (0): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (idconv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (1): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (2): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (3): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (4): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (5): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (6): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (7): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#     )
#     (6): Sequential(
#       (0): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#         (idconv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (1): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (2): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (3): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (4): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (5): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (6): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (7): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (8): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (9): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (10): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (11): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (12): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (13): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (14): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (15): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (16): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (17): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (18): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (19): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (20): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (21): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (22): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (23): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (24): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (25): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (26): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (27): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (28): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (29): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (1): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#           (2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (3): SE_Module(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#             (relu): ReLU(inplace)
#             (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (30): SE_ResBlock(
#         (convs): Sequential(
#           (0): Sequential(
#             (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
#   (407): Sigmoid()
#   (408): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (409): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (410): ReLU(inplace)
#   (411): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (412): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (413): ReLU(inplace)
#   (414): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (415): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (416): AdaptiveAvgPool2d(output_size=1)
#   (417): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (418): ReLU(inplace)
#   (419): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (420): Sigmoid()
#   (421): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (422): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (423): ReLU(inplace)
#   (424): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (425): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (426): ReLU(inplace)
#   (427): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (428): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (429): AdaptiveAvgPool2d(output_size=1)
#   (430): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (431): ReLU(inplace)
#   (432): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (433): Sigmoid()
#   (434): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (435): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (436): ReLU(inplace)
#   (437): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (438): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (439): ReLU(inplace)
#   (440): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (441): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (442): AdaptiveAvgPool2d(output_size=1)
#   (443): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (444): ReLU(inplace)
#   (445): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (446): Sigmoid()
#   (447): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (448): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (449): ReLU(inplace)
#   (450): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (451): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (452): ReLU(inplace)
#   (453): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (454): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (455): AdaptiveAvgPool2d(output_size=1)
#   (456): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (457): ReLU(inplace)
#   (458): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (459): Sigmoid()
#   (460): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (461): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (462): ReLU(inplace)
#   (463): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (464): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (465): ReLU(inplace)
#   (466): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (467): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (468): AdaptiveAvgPool2d(output_size=1)
#   (469): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (470): ReLU(inplace)
#   (471): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (472): Sigmoid()
#   (473): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (474): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (475): ReLU(inplace)
#   (476): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (477): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (478): ReLU(inplace)
#   (479): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (480): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (481): AdaptiveAvgPool2d(output_size=1)
#   (482): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (483): ReLU(inplace)
#   (484): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (485): Sigmoid()
#   (486): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (487): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (488): ReLU(inplace)
#   (489): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (490): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (491): ReLU(inplace)
#   (492): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (493): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (494): AdaptiveAvgPool2d(output_size=1)
#   (495): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (496): ReLU(inplace)
#   (497): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (498): Sigmoid()
#   (499): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (500): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (501): ReLU(inplace)
#   (502): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (503): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (504): ReLU(inplace)
#   (505): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (506): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (507): AdaptiveAvgPool2d(output_size=1)
#   (508): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (509): ReLU(inplace)
#   (510): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (511): Sigmoid()
#   (512): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (513): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (514): ReLU(inplace)
#   (515): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (516): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (517): ReLU(inplace)
#   (518): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (519): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (520): AdaptiveAvgPool2d(output_size=1)
#   (521): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (522): ReLU(inplace)
#   (523): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (524): Sigmoid()
#   (525): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (526): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (527): ReLU(inplace)
#   (528): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (529): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (530): ReLU(inplace)
#   (531): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (532): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (533): AdaptiveAvgPool2d(output_size=1)
#   (534): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (535): ReLU(inplace)
#   (536): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (537): Sigmoid()
#   (538): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (539): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (540): ReLU(inplace)
#   (541): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (542): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (543): ReLU(inplace)
#   (544): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (545): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (546): AdaptiveAvgPool2d(output_size=1)
#   (547): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (548): ReLU(inplace)
#   (549): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (550): Sigmoid()
#   (551): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (552): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (553): ReLU(inplace)
#   (554): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (555): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (556): ReLU(inplace)
#   (557): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (558): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (559): AdaptiveAvgPool2d(output_size=1)
#   (560): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (561): ReLU(inplace)
#   (562): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (563): Sigmoid()
#   (564): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (565): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (566): ReLU(inplace)
#   (567): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (568): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (569): ReLU(inplace)
#   (570): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (571): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (572): AdaptiveAvgPool2d(output_size=1)
#   (573): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (574): ReLU(inplace)
#   (575): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (576): Sigmoid()
#   (577): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (578): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (579): ReLU(inplace)
#   (580): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (581): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (582): ReLU(inplace)
#   (583): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (584): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (585): AdaptiveAvgPool2d(output_size=1)
#   (586): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (587): ReLU(inplace)
#   (588): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (589): Sigmoid()
#   (590): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (591): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (592): ReLU(inplace)
#   (593): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (594): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (595): ReLU(inplace)
#   (596): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (597): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (598): AdaptiveAvgPool2d(output_size=1)
#   (599): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (600): ReLU(inplace)
#   (601): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (602): Sigmoid()
#   (603): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (604): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (605): ReLU(inplace)
#   (606): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (607): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (608): ReLU(inplace)
#   (609): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (610): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (611): AdaptiveAvgPool2d(output_size=1)
#   (612): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (613): ReLU(inplace)
#   (614): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (615): Sigmoid()
#   (616): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (617): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (618): ReLU(inplace)
#   (619): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (620): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (621): ReLU(inplace)
#   (622): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (623): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (624): AdaptiveAvgPool2d(output_size=1)
#   (625): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (626): ReLU(inplace)
#   (627): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (628): Sigmoid()
#   (629): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (630): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (631): ReLU(inplace)
#   (632): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (633): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (634): ReLU(inplace)
#   (635): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (636): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (637): AdaptiveAvgPool2d(output_size=1)
#   (638): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (639): ReLU(inplace)
#   (640): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (641): Sigmoid()
#   (642): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (643): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (644): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (645): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (646): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (647): ReLU(inplace)
#   (648): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (649): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (650): ReLU(inplace)
#   (651): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (652): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (653): AdaptiveAvgPool2d(output_size=1)
#   (654): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (655): ReLU(inplace)
#   (656): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (657): Sigmoid()
#   (658): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (659): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (660): ReLU(inplace)
#   (661): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (662): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (663): ReLU(inplace)
#   (664): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (665): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (666): AdaptiveAvgPool2d(output_size=1)
#   (667): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (668): ReLU(inplace)
#   (669): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (670): Sigmoid()
#   (671): AdaptiveAvgPool2d(output_size=1)
#   (672): AdaptiveMaxPool2d(output_size=1)
#   (673): Flatten()
#   (674): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (675): Dropout(p=0.25)
#   (676): Linear(in_features=4096, out_features=512, bias=True)
#   (677): ReLU(inplace)
#   (678): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (679): Dropout(p=0.5)
#   (680): Linear(in_features=512, out_features=1108, bias=True)
# )], add_time=True, silent=False)

# %%
# get prediction of test dataset
preds, _ = learn.get_preds(ds_type=DatasetType.Test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-b2a6c29280fd> in <module>
#       1 # get prediction of test dataset
# ----> 2 preds, _ = learn.get_preds(ds_type=DatasetType.Test)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(self, ds_type, with_loss, n_batch, pbar)
#     334         lf = self.loss_func if with_loss else None
#     335         return get_preds(self.model, self.dl(ds_type), cb_handler=CallbackHandler(self.callbacks),
# --> 336                          activ=_loss_func2activ(self.loss_func), loss_func=lf, n_batch=n_batch, pbar=pbar)
#     337
#     338     def pred_batch(self, ds_type:DatasetType=DatasetType.Valid, batch:Tuple=None, reconstruct:bool=False, with_dropout:bool=False) -> List[Tensor]:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(model, dl, pbar, cb_handler, activ, loss_func, n_batch)
#      42     "Tuple of predictions and targets, and optional losses (if `loss_func`) using `dl`, max batches `n_batch`."
#      43     res = [torch.cat(o).cpu() for o in
# ---> 44            zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#      45     if loss_func is not None:
#      46         with NoneReduceOnCPU(loss_func) as lf: res.append(lf(res[0], res[1]))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      57         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      58             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
# ---> 59             val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#      60             val_losses.append(val_loss)
#      61             if not is_listy(yb): yb = [yb]
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# TypeError: forward() missing 1 required positional argument: 'yb'

# %%
# check length
len(preds)
# Out:
# 19897

# %%
#preds

# %%
# get the categories
preds_cat = preds.argmax(dim=-1)

# %%
# get the names
preds_names = learn.data.test_ds.x.items

# %%
preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3][:3] for x in preds_names]
# including sX
#preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3] for x in preds_names]

# %%
df_preds = pd.DataFrame({'id_code': preds_names, 'sirna': preds.argmax(dim=-1)})

# %%
df_preds.head()
# Out:
#           id_code  sirna
# 0  HEPG2-08_1_B03    132
# 1  HEPG2-08_1_B04    445
# 2  HEPG2-08_1_B05    132
# 3  HEPG2-08_1_B06    577
# 4  HEPG2-08_1_B07    132

# %%
df_preds.to_csv('sub/'+model+'.csv.gz', index=False, compression='gzip')

# %%
# !kaggle competitions submit -c recursion-cellular-image-classification -f sub/{model}.csv.gz -m "{model}"
# Out:
# 100%|██████████████████████████████████████| 55.3k/55.3k [00:02<00:00, 19.3kB/s]
# Successfully submitted to Recursion Cellular Image Classification

# %% [markdown]
# ### TTA

# %%
# get TTA prediction of test dataset
learn.to_fp32();
preds, _ = learn.TTA(ds_type=DatasetType.Test)

# %%
# check length
len(preds)

# %%
#preds

# %%
# get the categories
preds_cat = preds.argmax(dim=-1)

# %%
# get the names
preds_names = learn.data.test_ds.x.items

# %%
preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3][:3] for x in preds_names]
# including sX
#preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3] for x in preds_names]

# %%
df_preds = pd.DataFrame({'id_code': preds_names, 'sirna': preds.argmax(dim=-1)})

# %%
df_preds.head()

# %%
df_preds.to_csv('sub/'+model+'_TTA.csv.gz', index=False, compression='gzip')

# %%
# !kaggle competitions submit -c recursion-cellular-image-classification -f sub/{model}_TTA.csv.gz -m "{model}"

# %% [markdown]
# # Others

# %% [markdown]
# ## Callback

# %%
# https://docs.fast.ai/callback.html#callback

# %%
# https://docs.fast.ai/callbacks.general_sched.html
def grl_scheduling(learn, n_cycles):
    '''Gradient reversal layer scheduling'''
    n = len(learn.data.train_dl)
    phases = [(TrainingPhase(n).schedule_hp('grl_factor', grl, anneal=annealing_cos))
              for i in range(n_cycles)]
    sched = GeneralScheduler(learn, phases)
    learn.callbacks.append(sched)
    #learn. ??
    
    #if cycle_mult != 1:
    #    total_epochs = int(cycle_len * (1 - (cycle_mult)**n_cycles)/(1-cycle_mult)) 
    #else: total_epochs = n_cycles * cycle_len
    #learn.fit(total_epochs)

# %%
# https://docs.fast.ai/callback.html#OptimWrapper
# OptimWrapper needed with the 'grl' parameter?

# %%
# Einfacher Callback mit nur 'on_train_begin'???

# Oder besser (?): monkey-patch optimizer mit 'grl' Variable
# und dann Adaptierung der 'grl_scheduling' Funktion!
