# %% [markdown]
# # Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd

from fastai.vision import *
from fastai.vision.models.xresnet import *

# for datablock API
from fastai.vision.image import _resolve_tfms, _get_crop_target, _round_multiple, _get_resize_target, _affine_grid, _grid_sample, _affine_mult

# for XResNet
#from fastai.vision.models.xresnet import act_fn, init_cnn, conv, noop, conv_layer, ResBlock, filt_sz

# %%
from fastai.callbacks import CSVLogger, ReduceLROnPlateauCallback, SaveModelCallback

# %%
from nb_new_data_augmentation_adacos import *

# %%
from efficientnet_pytorch import *

# %%
import pdb

# %%
__version__
# Out:
# '1.0.57'

# %% [markdown]
# # 6D image test

# %%
class Image6D(Image):
    "Support applying transforms to image data in `px`."
    def __init__(self, px:Tensor):
        self._px = px
        self._logit_px=None
        self._flow=None
        self._affine_mat=None
        self.sample_kwargs = {}

    def _repr_image_format(self, format_str):
        with BytesIO() as str_buffer:
            #plt.imsave(str_buffer, image2np(self.px[:3]), format=format_str)
            plt.imsave(str_buffer, 
                       np.concatenate((image2np(self.px[:3]), 
                                       image2np(self.px[3:])), axis=1),
                       format=format_str)
            return str_buffer.getvalue()

# %%
def open_image_6D(fn:PathOrStr, div:bool=True, convert_mode:str='L', cls:type=Image6D,
        after_open:Callable=None)->Image:
    "Return `Image` object created from image in file `fn`."
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
        
        x = []
        for i in range(6):
            c = PIL.Image.open(fn+'_w'+str(i+1)+'.png').convert(convert_mode)
            if after_open: c = after_open(c)
            c = np.asarray(c)
            c = torch.from_numpy(c.astype(np.float32, copy=False))
            x.append(c)
            
    x = torch.stack(x)
    if div: x.div_(255)
    return cls(x)

# %%
#PATH_trunc = 'train/HEPG2-01/Plate1/B02_s1' # path is missing suffix "_w1.png"
#open_image_6D(PATH_trunc)

# %% [markdown]
# # Dataset setup

# %%
class ImageList6D(ImageList): #ImageList
    def __init__(self, *args, convert_mode='L', after_open:Callable=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.convert_mode,self.after_open = convert_mode,after_open
        self.copy_new.append('convert_mode')
        self.c,self.sizes = 6,{}
        
    def open(self, fn):
        "Open image in `fn`, subclass and overwrite for custom behavior."
        return open_image_6D(fn, convert_mode=self.convert_mode, after_open=self.after_open)

#    def show(self, img):
#        #return torch.cat((img[i][:3], img[i][3:]), dim=1)
#        show_image(img)
    
    # https://docs.fast.ai/tutorial.itemlist.html#Advanced-show-methods
    def show_xys(self, xs, ys, figsize:Tuple[int,int]=(15,10), **kwargs):
        "Show the `xs` and `ys` on a figure of `figsize`. `kwargs` are passed to the show method."
        rows = int(math.sqrt(len(xs)))
        fig, axs = plt.subplots(rows,rows,figsize=figsize)
        for i, ax in enumerate(axs.flatten() if rows > 1 else [axs]):
            #xs[i].show(ax=ax, y=ys[i], **kwargs)
            img = Image6D(torch.cat((xs[i].data[:3], xs[i].data[3:]), dim=2)) # works but not elegant?
            #img = Image6D(xs[i]) # does not work?
            img.show(ax=ax, y=ys[i], **kwargs)
        plt.tight_layout()

# %%
#def show_image(img:Image, ax:plt.Axes=None, figsize:tuple=(3,3), hide_axis:bool=True, cmap:str='binary',
#                alpha:float=None, **kwargs)->plt.Axes:
#    "Display `Image` in notebook."
#    if ax is None: fig,ax = plt.subplots(figsize=figsize)
#    pdb.set_trace()
#    #ax.imshow(image2np(img.data), cmap=cmap, alpha=alpha, **kwargs)
#    ax.imshow(np.concatenate((image2np(self.px[:3]),
#                              image2np(self.px[3:])), axis=1),
#              cmap=cmap, alpha=alpha, **kwargs)
#    if hide_axis: ax.axis('off')
#    return ax

# %% [markdown]
# ## Full dataset

# %% [markdown]
# ### Dataset raw files

# %%
df_train = pd.read_csv('full_train_dataset_valid-split-ex_v2_20190727.csv', index_col=0)
df_test = pd.read_csv('full_test_dataset_v2_20190727.csv', index_col=0)

# %%
df_train.shape
# Out:
# (73030, 5)

# %%
df_train.tail()
# Out:
#                         path experiment  sirna        multi  valid
# 36510  U2OS-03/Plate4/O19_s2    U2OS-03    103  U2OS-03 103      1
# 36511  U2OS-03/Plate4/O20_s2    U2OS-03    202  U2OS-03 202      1
# 36512  U2OS-03/Plate4/O21_s2    U2OS-03    824  U2OS-03 824      1
# 36513  U2OS-03/Plate4/O22_s2    U2OS-03    328  U2OS-03 328      1
# 36514  U2OS-03/Plate4/O23_s2    U2OS-03    509  U2OS-03 509      1

# %%
df_test.tail()
# Out:
#                         path experiment
# 19892  U2OS-05/Plate4/O19_s2    U2OS-05
# 19893  U2OS-05/Plate4/O20_s2    U2OS-05
# 19894  U2OS-05/Plate4/O21_s2    U2OS-05
# 19895  U2OS-05/Plate4/O22_s2    U2OS-05
# 19896  U2OS-05/Plate4/O23_s2    U2OS-05

# %% [markdown]
# ### Color augmentation transformation

# %% [markdown]
# "Color Augmentation: Color variability can be increased by applying random color transformations to original training samples. We perform color augmentation by transforming every color channels Ic ← ac · Ic + bc, where ac and bc are drawn from uniform distributions ac ∼ U [0.9, 1.1] and bc ∼ U [−10, +10]." from Domain-adversarial neural networks to address the appearance variability of histopathology images

# %%
# from https://github.com/fastai/fastai/blob/master/fastai/vision/transform.py#L137
#def _rgb_randomize(x, channel:int=None, thresh:float=0.3):
#    "Randomize one of the channels of the input image"
#    if channel is None: channel = np.random.randint(0, x.shape[0] - 1)
#    x[channel] = torch.rand(x.shape[1:]) * np.random.uniform(0, thresh)
#    return x
#
#rgb_randomize = TfmPixel(_rgb_randomize)

# %%
# Scaling factor comes from byte tensor?
#10/255 = 0.0392156862745098

# %%
def _color_augmentation(x):
    "Randomize all channels of the input image"
    channel_count = x.shape[0] - 1
    
    # by transforming every color channels Ic ← ac · Ic + bc, 
    # where ac and bc are drawn from uniform distributions 
    # ac ∼ U [0.9, 1.1] and 
    # bc ∼ U [−10, +10].
    
    # x [0,1]
    
    for c in range(channel_count):
        #pdb.set_trace()
        #print(x.min(), x.max())
        ac = np.random.uniform(0.9, 1.1) #np.random.uniform(0.9, 1.1)
        bc = np.random.uniform(-0.1,0.1) #np.random.uniform(-10, 10)
        x[c] = x[c] * ac + bc
        
        # clipping to min 0 and max 1
        x[c] = torch.clamp(x[c], 0., 1.)
    
    return x

color_augmentation = TfmPixel(_color_augmentation)

# %% [markdown]
# ### Transforms setup

# %%
## AdaCos-SE-XResNet50c --> FP32 !!!
# TRAINING
#sz, bs = 128, 8*20 # 7430MiB /  7952MiB
#sz, bs = 256, 8*5 # 7475MiB /  7952MiB & 7395MiB /  7952MiB
#sz, bs = 512, 8 #
# PREDICTION
#sz, bs = 256, 8*25 # 5391MiB /  7952MiB
#sz, bs = 256, 8*40 # 7741MiB /  7952MiB
#sz, bs = 512, 8*5 # 6051MiB /  7952MiB
# DATA AUGM W/O AdaCos
#sz, bs = 128, 8*42 # 7937MiB /  7952MiB
#sz, bs = 256, 8*13 # 
#sz, bs = 512, 8*3 # 


## EfficientNet-B3
#sz, bs = 300, 8 # 4167MiB /  7952MiB
sz, bs = 300, 8*2 # 78??MiB /  7952MiB // FP16: 4397MiB /  7952MiB
#sz, bs = 300, 8*4 # FP16: 7805MiB /  7952MiB

# %%
sz, bs
# Out:
# (300, 16)

# %%
# normal tfms
#tfms = get_transforms()

# %%
# extended tfms
#tfms = get_transforms(do_flip=True, flip_vert=True, 
#                      max_rotate=90.0, max_zoom=1.1, 
#                      max_lighting=0.2, max_warp=0.2, 
#                      p_affine=0.75, p_lighting=0.75, 
#                      xtra_tfms=[color_augmentation()])
#
# crop_pad: https://forums.fast.ai/t/misc-issues/35386/10

# %%
# extended tfms
tfms = get_transforms(do_flip=True, flip_vert=True, 
                      max_rotate=90.0, max_zoom=1.1, 
                      max_lighting=0.2, max_warp=0.2, 
                      p_affine=0.75, p_lighting=0.75, 
                      xtra_tfms=[color_augmentation(), 
                                 cutout(n_holes=(1,4), length=(10, 100), p=.75)])

# %%
#tfms = [[crop(size=sz, row_pct=(0,1), col_pct=(0,1))], []]

# %%
#tfms

# %%
# change "crop_pad" from get_transforms to "crop"
# uniform for random cropping
tfms[0][0] = crop(size=sz, row_pct=uniform(0,1), col_pct=uniform(0,1))
tfms[1][0] = crop(size=sz, row_pct=uniform(0,1), col_pct=uniform(0,1))

# %%
# train crop
tfms[0][0].kwargs['row_pct'], tfms[0][0].kwargs['col_pct']
# Out:
# (0.21093781310437087, 0.5308227223790896)

# %%
# valid crop
tfms[1][0].kwargs['row_pct'], tfms[1][0].kwargs['col_pct']
# Out:
# (0.4340574739273739, 0.08500409723575297)

# %%
#tfms

# %% [markdown]
# ### Dataset definition

# %%
# VALID SPLIT (incl. tfms)
data = (ImageList6D.from_df(df_train, path='train')
        .split_from_df(col=-1) # split_by_rand_pct()
        .label_from_df(cols=-3)
        .add_test(ImageList6D.from_df(df_test, path='test'))
        .transform(tfms)#, size=sz) # remove size so we get the crop size!
        .databunch(bs=bs))

# %%
# FULL DATASET (incl. tfms)
#data = (ImageList6D.from_df(df_train, path='train')
#        .split_none() # !!!
#        .label_from_df(cols=-3)
#        .add_test(ImageList6D.from_df(df_test, path='test'))
#        .transform(tfms, size=sz)
#        .databunch(bs=bs))

# %%
# VALID SPLIT PREDICTION (NO tfms)
#data = (ImageList6D.from_df(df_train, path='train')
#        .split_from_df(col=-1) 
#        .label_from_df(cols=-3) # label_delim=' ' for MultiCategoryList !
#        .add_test(ImageList6D.from_df(df_test, path='test'))
#        .transform(size=sz) # !!!
#        .databunch(bs=bs))

# %%
# FULL DATASET PREDICTION (NO tfms)
#data = (ImageList6D.from_df(df_train, path='train')
#        .split_none() # !!!
#        .label_from_df(cols=-3)
#        .add_test(ImageList6D.from_df(df_test, path='test'))
#        .transform(size=sz)
#        .databunch(bs=bs))

# %%
data.batch_stats()
# Out:
# [tensor([0.0507, 0.0631, 0.0473, 0.0483, 0.0509, 0.0343]),
#  tensor([0.0575, 0.0733, 0.0562, 0.0679, 0.0598, 0.0330])]

# %%
# From https://github.com/recursionpharma/rxrx1-utils/blob/master/rxrx/main.py
# The mean and stds for each of the channels
GLOBAL_PIXEL_STATS = (np.array([6.74696984, 14.74640167, 10.51260864,
                                10.45369445,  5.49959796, 9.81545561]),
                       np.array([7.95876312, 12.17305868, 5.86172946,
                                 7.83451711, 4.701167, 5.43130431]))

stats_mean = torch.tensor(GLOBAL_PIXEL_STATS[0]/255).float()
stats_var = torch.tensor(GLOBAL_PIXEL_STATS[1]/255).float()

# %%
stats_mean, stats_var
# Out:
# (tensor([0.0265, 0.0578, 0.0412, 0.0410, 0.0216, 0.0385]),
#  tensor([0.0312, 0.0477, 0.0230, 0.0307, 0.0184, 0.0213]))

# %%
# Batch-wise normalization should be enough because the deviation is max. 6%
# see "rcic_v10_inspect_image_data.ipynb" for analysis.
#data.normalize() # https://docs.fast.ai/vision.data.html#ImageDataBunch.batch_stats

data.normalize([tensor([0.0456, 0.0702, 0.0447, 0.0468, 0.0407, 0.0399]),
                tensor([0.0644, 0.0733, 0.0536, 0.0633, 0.0555, 0.0392])])

# efficientnet stats https://github.com/lukemelas/EfficientNet-PyTorch#example-classification
#data.normalize(([0.485, 0.456, 0.406, 0.485, 0.456, 0.406],
#               [0.229, 0.224, 0.225, 0.229, 0.224, 0.225]))

# mean of mean, and mean of std from rcic_v10_inspect_image_data.ipynb
#data.normalize([stats_mean, stats_var])
# Out:
# ImageDataBunch;
#
# Train: LabelList (57554 items)
# x: ImageList6D
# Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300)
# y: CategoryList
# 513,840,1020,254,144
# Path: train;
#
# Valid: LabelList (15476 items)
# x: ImageList6D
# Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300)
# y: CategoryList
# 352,361,503,505,70
# Path: train;
#
# Test: LabelList (39794 items)
# x: ImageList6D
# Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300),Image6D (6, 300, 300)
# y: EmptyLabelList
# ,,,,
# Path: train

# %%
#data.batch_stats()

# %%
data.batch_size
# Out:
# 16

# %%
#data.stats # results is copied below
#[tensor([0.0456, 0.0702, 0.0447, 0.0468, 0.0407, 0.0399]),
# tensor([0.0644, 0.0733, 0.0536, 0.0633, 0.0555, 0.0392])]

# %%
#data

# %%
data.c, len(data.classes), data.classes[-5:]
# Out:
# (1108, 1108, [1103, 1104, 1105, 1106, 1107])

# %%
data.train_ds[0]
# Out:
# (Image6D (6, 300, 300), Category 513)

# %%
#data.classes

# %%
data.train_ds[0][1], data.train_ds[0][1].data
# Out:
# (Category 513, 513)

# %%
data.train_ds[0][0]
# Out:
# Image6D (6, 300, 300)

# %%
data.train_ds[0][0].data.shape
# Out:
# torch.Size([6, 300, 300])

# %%
#data.train_ds[0][0].apply_tfms(crop(size=300, row_pct=(0,1), col_pct=(0,1)))

# %%
### ORIGINAL 512px NO TFMS
data.train_ds[0][0]
# Out:
# Image6D (6, 300, 300)

# %% [markdown]
# # Model setup

# %% [markdown]
# ## EfficientNet

# %%
# 3d to 6d from old/rcic_multicat_v9_resnet50-pretrained_colaug.ipynb

# %%
from efficientnet_pytorch.utils import get_same_padding_conv2d, round_filters, round_repeats, relu_fn
from efficientnet_pytorch.model import MBConvBlock, load_pretrained_weights

# %%
# put feature extractor into forward method
class EfficientNet(nn.Module):
    """
    An EfficientNet model. Most easily loaded with the .from_name or .from_pretrained methods
    Args:
        blocks_args (list): A list of BlockArgs to construct blocks
        global_params (namedtuple): A set of GlobalParams shared between blocks
    Example:
        model = EfficientNet.from_pretrained('efficientnet-b0')
    """

    def __init__(self, blocks_args=None, global_params=None):
        super().__init__()
        assert isinstance(blocks_args, list), 'blocks_args should be a list'
        assert len(blocks_args) > 0, 'block args must be greater than 0'
        self._global_params = global_params
        self._blocks_args = blocks_args

        # Get static or dynamic convolution depending on image size
        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)

        # Batch norm parameters
        bn_mom = 1 - self._global_params.batch_norm_momentum
        bn_eps = self._global_params.batch_norm_epsilon

        # Stem
        in_channels = 3  # rgb
        out_channels = round_filters(32, self._global_params)  # number of output channels
        self._conv_stem = Conv2d(in_channels, out_channels, kernel_size=3, stride=2, bias=False)
        self._bn0 = nn.BatchNorm2d(num_features=out_channels, momentum=bn_mom, eps=bn_eps)

        # Build blocks
        self._blocks = nn.ModuleList([])
        for block_args in self._blocks_args:

            # Update block input and output filters based on depth multiplier.
            block_args = block_args._replace(
                input_filters=round_filters(block_args.input_filters, self._global_params),
                output_filters=round_filters(block_args.output_filters, self._global_params),
                num_repeat=round_repeats(block_args.num_repeat, self._global_params)
            )

            # The first block needs to take care of stride and filter size increase.
            self._blocks.append(MBConvBlock(block_args, self._global_params))
            if block_args.num_repeat > 1:
                block_args = block_args._replace(input_filters=block_args.output_filters, stride=1)
            for _ in range(block_args.num_repeat - 1):
                self._blocks.append(MBConvBlock(block_args, self._global_params))

        # Head
        in_channels = block_args.output_filters  # output of final block
        out_channels = round_filters(1280, self._global_params)
        self._conv_head = Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self._bn1 = nn.BatchNorm2d(num_features=out_channels, momentum=bn_mom, eps=bn_eps)

        # Final linear layer
        #self._dropout = self._global_params.dropout_rate
        #self._fc = nn.Linear(out_channels, self._global_params.num_classes)

    def forward(self, inputs):
        """ Returns output of the final convolution layer """

        # Stem
        x = relu_fn(self._bn0(self._conv_stem(inputs)))

        # Blocks
        for idx, block in enumerate(self._blocks):
            drop_connect_rate = self._global_params.drop_connect_rate
            if drop_connect_rate:
                drop_connect_rate *= float(idx) / len(self._blocks)
            x = block(x, drop_connect_rate=drop_connect_rate)

        # Head
        x = relu_fn(self._bn1(self._conv_head(x)))

        return x

    #def forward(self, inputs):
    #    """ Calls extract_features to extract features, applies final linear layer, and returns logits. """
    #
    #    # Convolution layers
    #    x = self.extract_features(inputs)
    #
    #    # Pooling and final linear layer
    #    x = F.adaptive_avg_pool2d(x, 1).squeeze(-1).squeeze(-1)
    #    if self._dropout:
    #        x = F.dropout(x, p=self._dropout, training=self.training)
    #    x = self._fc(x)
    #    return x

    @classmethod
    def from_name(cls, model_name, override_params=None):
        cls._check_model_name_is_valid(model_name)
        blocks_args, global_params = get_model_params(model_name, override_params)
        return EfficientNet(blocks_args, global_params)

    @classmethod
    def from_pretrained(cls, model_name, num_classes=1000):
        model = EfficientNet.from_name(model_name, override_params={'num_classes': num_classes})
        load_pretrained_weights(model, model_name, load_fc=(num_classes == 1000))
        return model

    @classmethod
    def get_image_size(cls, model_name):
        cls._check_model_name_is_valid(model_name)
        _, _, res, _ = efficientnet_params(model_name)
        return res

    @classmethod
    def _check_model_name_is_valid(cls, model_name, also_need_pretrained_weights=False):
        """ Validates model name. None that pretrained weights are only available for
        the first four models (efficientnet-b{i} for i in 0,1,2,3) at the moment. """
        num_models = 4 if also_need_pretrained_weights else 8
        valid_models = ['efficientnet_b'+str(i) for i in range(num_models)]
        if model_name.replace('-','_') not in valid_models:
            raise ValueError('model_name should be one of: ' + ', '.join(valid_models))

# %%
from torch.utils import model_zoo

# %%
url_map = {
    'efficientnet-b0': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b0-355c32eb.pth',
    'efficientnet-b1': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b1-f1951068.pth',
    'efficientnet-b2': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b2-8bb594d6.pth',
    'efficientnet-b3': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b3-5fb5a3c3.pth',
    'efficientnet-b4': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b4-6ed6700e.pth',
    'efficientnet-b5': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b5-b6417697.pth',
    'efficientnet-b6': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b6-c76e70fd.pth',
    'efficientnet-b7': 'http://storage.googleapis.com/public-models/efficientnet/efficientnet-b7-dcc49843.pth',
}

# %%
# adapt load function to only load weights for feature extractor stage
def load_pretrained_weights(model, model_name, load_fc=True):
    """ Loads pretrained weights, and downloads if loading for the first time. """
    state_dict = model_zoo.load_url(url_map[model_name])
    #if load_fc:
    #    model.load_state_dict(state_dict)
    #else:
    state_dict.pop('_fc.weight')
    state_dict.pop('_fc.bias')
    res = model.load_state_dict(state_dict, strict=False)
        #assert str(res.missing_keys) == str(['_fc.weight', '_fc.bias']), 'issue loading pretrained weights'
    print('Loaded pretrained weights for {}'.format(model_name))

# %%
# b3: input size = 300
#efficientnet_b3 = EfficientNet.from_name('efficientnet-b3')
efficientnet_b3f = EfficientNet.from_pretrained('efficientnet-b3')
# Out:
# Loaded pretrained weights for efficientnet-b3

# %%
#efficientnet_b3f

# %%
efficientnet_b3f._conv_stem, type(efficientnet_b3f._conv_stem)
# Out:
# (Conv2dStaticSamePadding(
#    3, 40, kernel_size=(3, 3), stride=(2, 2), bias=False
#    (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#  ), efficientnet_pytorch.utils.Conv2dStaticSamePadding)

# %%
utils.Conv2dStaticSamePadding(6, 40, kernel_size=(3, 3), stride=(2, 2), bias=False, image_size=300)
# Out:
# Conv2dStaticSamePadding(
#   6, 40, kernel_size=(3, 3), stride=(2, 2), bias=False
#   (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
# )

# %%
p_dict = {pn: p for pn, p in efficientnet_b3f._conv_stem.named_parameters()}

# %%
p_dict.keys()
# Out:
# dict_keys(['weight'])

# %%
p_dict['weight'].shape, p_dict['weight'].requires_grad
# Out:
# (torch.Size([40, 3, 3, 3]), True)

# %%
old_weight = p_dict['weight'].detach()

# %%
old_weight.shape, old_weight.requires_grad
# Out:
# (torch.Size([40, 3, 3, 3]), False)

# %%
new_weight = torch.cat((old_weight, old_weight), dim=1)

# %%
new_weight.shape, new_weight.requires_grad
# Out:
# (torch.Size([40, 6, 3, 3]), False)

# %%
def show_input_stage_weights(weight=None, nrows=2, ncols=3):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols)
    k = 0
    for i in range(nrows):
        for j in range(ncols):
            if nrows > 1:
                ax[i,j].set_title(k)
                ax[i,j].imshow(weight[0][k])
                ax[i,j].axis("off")
            else:
                ax[j].set_title(k)
                ax[j].imshow(weight[0][k])
                ax[j].axis("off")
            k += 1

# %%
# plot old_weight
#show_input_stage_weights(old_weight, nrows=1)

# %%
# plot new_weight
#show_input_stage_weights(new_weight)

# %%
# replace first conv layer with a 6-channel version
efficientnet_b3f._conv_stem = utils.Conv2dStaticSamePadding(6, 40, kernel_size=(3, 3),
                                                           stride=(2, 2), bias=False, image_size=300)

# %%
efficientnet_b3f._conv_stem
# Out:
# Conv2dStaticSamePadding(
#   6, 40, kernel_size=(3, 3), stride=(2, 2), bias=False
#   (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
# )

# %%
efficientnet_b3f._conv_stem.weight.shape
# Out:
# torch.Size([40, 6, 3, 3])

# %%
# set new_weights to nn.Parameter and overwrite it in the conv layer
efficientnet_b3f._conv_stem.weight = nn.Parameter(new_weight) # hand over requires_grad False?

# %%
# check if weight was loaded properly
assert torch.allclose(new_weight, efficientnet_b3f._conv_stem.weight)

# %%
efficientnet_b3f._conv_stem.weight.shape, efficientnet_b3f._conv_stem.weight.requires_grad
# Out:
# (torch.Size([40, 6, 3, 3]), True)

# %%
# network is in full train mode!
#[p.requires_grad for p in efficientnet_b3f.parameters()]

# %%
def set_rg(model=efficientnet_b3f, option=False):
    for param in model.parameters():
        param.requires_grad = option

# %%
set_rg()

# %%
# network is frozen
#[p.requires_grad for p in efficientnet_b3f.parameters()]

# %%
efficientnet_b3f._conv_stem.weight.requires_grad
# Out:
# False

# %%
# set input stage to trainable
efficientnet_b3f._conv_stem.weight.requires_grad = True

# %%
efficientnet_b3f._conv_stem.weight.requires_grad
# Out:
# True

# %%
efficientnet_b3f(torch.randn(1,6,300,300)).shape
# Out:
# torch.Size([1, 1536, 9, 9])

# %% [markdown]
# ### AdaCos-Head

# %%
def create_adacos_head(nf:int, lin_ftrs:Optional[Collection[int]]=None, ps:Floats=0.5,
                concat_pool:bool=True, bn_final:bool=False):
    #nc:int, 
    "Model head that takes `nf` features, runs through `lin_ftrs`, and about `nc` classes."
    
    lin_ftrs = [nf, 512, 512] if lin_ftrs is None else [nf] + lin_ftrs + [nc]
    # remove last 512 fc layer to reduce MODEL SIZE ??? ???
    
    ps = listify(ps)
    if len(ps) == 1: ps = [ps[0]/2] * (len(lin_ftrs)-2) + ps
    actns = [nn.ReLU(inplace=True)] * (len(lin_ftrs)-2) + [None]
    pool = AdaptiveConcatPool2d() if concat_pool else nn.AdaptiveAvgPool2d(1)
    layers = [pool, Flatten()]
    for ni,no,p,actn in zip(lin_ftrs[:-1], lin_ftrs[1:], ps, actns):
        layers += bn_drop_lin(ni, no, True, p, actn)
    if bn_final: layers.append(nn.BatchNorm1d(lin_ftrs[-1], momentum=0.01))
    #layers.append(AdaCos(lin_ftrs[-1], nc))
    return nn.Sequential(*layers)

# %%
adacos_head = create_adacos_head(nf=1536*2)

# %%
adacos_head
# Out:
# Sequential(
#   (0): AdaptiveConcatPool2d(
#     (ap): AdaptiveAvgPool2d(output_size=1)
#     (mp): AdaptiveMaxPool2d(output_size=1)
#   )
#   (1): Flatten()
#   (2): BatchNorm1d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): Dropout(p=0.25, inplace=False)
#   (4): Linear(in_features=3072, out_features=512, bias=True)
#   (5): ReLU(inplace=True)
#   (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=512, out_features=512, bias=True)
# )

# %%
adacos_head(torch.randn(2, 1536, 9, 9)).shape
# Out:
# torch.Size([2, 512])

# %%
# from https://github.com/4uiiurz1/pytorch-adacos/blob/master/metrics.py
class AdaCos(nn.Module):
    def __init__(self, num_features, num_classes, m=0.50):
        super(AdaCos, self).__init__()
        self.num_features = num_features
        self.n_classes = num_classes
        self.s = math.sqrt(2) * math.log(num_classes - 1)
        self.m = m
        self.W = nn.Parameter(torch.FloatTensor(num_classes, num_features))
        nn.init.xavier_uniform_(self.W)

    def forward(self, xb, yb):
        
        #print(yb.shape)
        #pdb.set_trace()
        
        # normalize features
        x = F.normalize(xb)
        # normalize weights
        W = F.normalize(self.W)
        # dot product
        logits = F.linear(x, W)
        
        # for training in non-AdaCos mode (= no yb date in the forward pass):
        if yb is None:
            print('yb = None')
            return logits
        
        # feature re-scale
        theta = torch.acos(torch.clamp(logits, -1.0 + 1e-7, 1.0 - 1e-7))
        one_hot = torch.zeros_like(logits)
        
        # ORIGINAL
        #one_hot.scatter_(1, yb.view(-1, 1).long(), 1)
        #with torch.no_grad():
        #    B_avg = torch.where(one_hot < 1, torch.exp(self.s * logits), torch.zeros_like(logits))
        #    B_avg = torch.sum(B_avg) / xb.size(0)
        #    #print(B_avg)
        #    theta_med = torch.median(theta[one_hot == 1])
        #    self.s = torch.log(B_avg) / torch.cos(torch.min(math.pi/4 * torch.ones_like(theta_med), theta_med))
        #    #print(self.s)
            
        # ADAPTED FOR CUTMIX TO GET MIXED SCALE PARAMETER
        with torch.no_grad():
            # FROM nb_new_data_augmentation_adacos2.py LINE 888
            # AND https://github.com/fastai/fastai/blob/master/fastai/callbacks/mixup.py#L40
            if yb.ndim == 2:# and target.shape[-1] >1:
                n_mod_patches = (yb.shape[-1] - 1) // 2
                #c_ = yb[:, 1:n_mod_patches + 1]
                c_ = yb[:, 0:n_mod_patches + 1]
                W_ = yb[:, n_mod_patches + 1:]
                self.s_scaled = []
                
                # this loop is only realdy needed when we have different probabilities inside a batch
                # which we do not have (right now)! So this could be cleaned up, but we leave until
                # we know we will not need the case with different probabilities in a batch.
                for k in range(n_mod_patches+1):
                    yb_new = c_[:, k].long()
                    #pdb.set_trace()
                    
                    one_hot.scatter_(1, yb_new.view(-1,1).long(), 1)
                    
                    B_avg = torch.where(one_hot < 1, torch.exp(self.s * logits), torch.zeros_like(logits))
                    B_avg = torch.sum(B_avg) / xb.size(0)
                    theta_med = torch.median(theta[one_hot == 1])
                    self.s = torch.log(B_avg) / torch.cos(torch.min(math.pi/4 * torch.ones_like(theta_med), theta_med))
                    
                    if k+1 == len(range(n_mod_patches+1)):
                        #self.s_scaled.append((1-W_[:, k-1]) * self.s)
                        self.s_scaled.append((1-W_[0, k-1]) * self.s)
                        # For more than two the sum of W_[:, :k] has to be used!!!
                    else:
                        #self.s_scaled.append(W_[:, k] * self.s)
                        self.s_scaled.append(W_[0, k] * self.s)
                    # Mixed B_avg & self.s and single are not really far off, but now we have it coded
                    # se we keep it (until it breaks something later).
                self.s = torch.add(*self.s_scaled)
                # Clean up, self.s_scaled is just a vector with the same entry multiple times
                # when it is not indexed above with W_[0,... !
            else:
                one_hot.scatter_(1, yb.view(-1,1).long(), 1)
                B_avg = torch.where(one_hot < 1, torch.exp(self.s * logits), torch.zeros_like(logits))
                B_avg = torch.sum(B_avg) / xb.size(0)
                theta_med = torch.median(theta[one_hot == 1])
                self.s = torch.log(B_avg) / torch.cos(torch.min(math.pi/4 * torch.ones_like(theta_med), theta_med))
        
        output = self.s * logits

        return output

# %%
class AdaCosNet(nn.Module):
    '''Simple AdaCosNet connecter to run xb through the feature extractor head
    and then feed xb and yb into the AdaCos layer.'''
    def __init__(self, body, head):
        super(AdaCosNet, self).__init__()
        self.body = body
        self.head = head
        self.adacos = AdaCos(512, 1108)
        
    def forward(self, xb, yb=None): # yb=None for training in non-AdaCos mode!
        features = self.body(xb)
        out = self.head(features)
        #print('xb.shape: ', xb.shape,', yb.shape: ', yb.shape)
        out = self.adacos(out, yb)
        #print('out: ',out.shape)
        #pdb.set_trace()
        return out

# %%
adacos_efficientnet_b3 = AdaCosNet(efficientnet_b3f, adacos_head)

# %%
adacos_efficientnet_b3(torch.randn(2,6,sz,sz)).shape
# Out:
# yb = None
# torch.Size([2, 1108])

# %%
adacos_efficientnet_b3(torch.randn(2,6,sz,sz), torch.tensor([513, 1])).shape
# Out:
# torch.Size([2, 1108])

# %%
test_target = torch.tensor(
    [[2.4700e+02, 3.3900e+02, 7.8362e-01],
     [2.3300e+02, 7.7400e+02, 7.8362e-01],
     [7.7400e+02, 1.3400e+02, 7.8362e-01],
     [6.9800e+02, 8.4700e+02, 7.8362e-01]])

# %%
adacos_efficientnet_b3(torch.randn(4,6,sz,sz), test_target).shape
# Out:
# torch.Size([4, 1108])

# %%
# Based on https://forums.fast.ai/t/teacher-forcing/29415/4
# https://forums.fast.ai/t/on-batch-begin-callback/35201/3
@dataclass
class AppendBatchTargs(Callback):
    learn:Learner
    def __init__(self, learn):
        super().__init__()
    def on_batch_begin(self, last_input, last_target, **kwargs):
        pdb.set_trace()
        return {'last_input':(last_input, last_target), 'last_target':last_target}

# %% [markdown]
# # Training

# %% [markdown]
# ## adacos_efficientnet_b3

# %%
learn = Learner(data, adacos_efficientnet_b3, metrics=[accuracy],
                callback_fns=[CSVLogger, AppendBatchTargs])#.to_fp16()

# %%
learn.callback_fns
# Out:
# [functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False),
#  fastai.callbacks.csv_logger.CSVLogger,
#  __main__.AppendBatchTargs]

# %%
learn.fit_one_cycle(1, max_lr=1e-5)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='3597', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# > <ipython-input-96-805f86812232>(10)on_batch_begin()
# -> return {'last_input':(last_input, last_target), 'last_target':last_target}
# (Pdb) ll
#   8  	    def on_batch_begin(self, last_input, last_target, **kwargs):
#   9  	        pdb.set_trace()
#  10  ->	        return {'last_input':(last_input, last_target), 'last_target':last_target}
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-99-b4dac46a6b76> in <module>
# ----> 1 learn.fit_one_cycle(1, max_lr=1e-5)
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     200         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     201         self.cb_fns_registered = True
# --> 202         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     203
#     204     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      98             cb_handler.on_epoch_begin()
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
# --> 100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/callback.py in on_batch_begin(self, xb, yb, train)
#     277         self.state_dict.update(dict(last_input=xb, last_target=yb, train=train,
#     278             stop_epoch=False, skip_step=False, skip_zero=False, skip_bwd=False))
# --> 279         self('batch_begin', mets = not self.state_dict['train'])
#     280         return self.state_dict['last_input'], self.state_dict['last_target']
#     281
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/callback.py in __call__(self, cb_name, call_mets, **kwargs)
#     249         if call_mets:
#     250             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# --> 251         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#     252
#     253     def set_dl(self, dl:DataLoader):
#
# ~/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/callback.py in _call_and_update(self, cb, cb_name, **kwargs)
#     239     def _call_and_update(self, cb, cb_name, **kwargs)->None:
#     240         "Call `cb_name` on `cb` and update the inner state."
# --> 241         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#     242         for k,v in new.items():
#     243             if k not in self.state_dict:
#
# <ipython-input-96-805f86812232> in on_batch_begin(self, last_input, last_target, **kwargs)
#       8     def on_batch_begin(self, last_input, last_target, **kwargs):
#       9         pdb.set_trace()
# ---> 10         return {'last_input':(last_input, last_target), 'last_target':last_target}
#
# <ipython-input-96-805f86812232> in on_batch_begin(self, last_input, last_target, **kwargs)
#       8     def on_batch_begin(self, last_input, last_target, **kwargs):
#       9         pdb.set_trace()
# ---> 10         return {'last_input':(last_input, last_target), 'last_target':last_target}
#
# ~/anaconda3/envs/fastai2/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/fastai2/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:

# %%
x = next(iter(learn.data.train_dl))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-788b1bac48f5> in <module>
# ----> 1 x = next(iter(learn.data.train_dl))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_data.py in proc_batch(self, b)
#      68         "Process batch `b` of `TensorImage`."
#      69         b = to_device(b, self.device)
# ---> 70         for f in listify(self.tfms): b = f(b)
#      71         return b
#      72
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py in _normalize_batch(b, mean, std, do_x, do_y)
#      63 def _normalize_batch(b:Tuple[Tensor,Tensor], mean:FloatTensor, std:FloatTensor, do_x:bool=True, do_y:bool=False)->Tuple[Tensor,Tensor]:
#      64     "`b` = `x`,`y` - normalize `x` array of imgs and `do_y` optionally `y`."
# ---> 65     (x,cint),y = b
#      66     #(x,cint,pgint,expint),y = b
#      67     #x,y = b
#
# ValueError: too many values to unpack (expected 2)

# %%
x[0]

# %%
# %debug
# Out:
# > /home/mmp/anaconda3/envs/fastai2/lib/python3.6/site-packages/fastai/vision/data.py(65)_normalize_batch()
#      63 def _normalize_batch(b:Tuple[Tensor,Tensor], mean:FloatTensor, std:FloatTensor, do_x:bool=True, do_y:bool=False)->Tuple[Tensor,Tensor]:
#      64     "`b` = `x`,`y` - normalize `x` array of imgs and `do_y` optionally `y`."
# ---> 65     (x,cint),y = b
#      66     mean,std = mean.to(x.device),std.to(x.device)
#      67     if do_x: x = normalize(x,mean,std)
#
# ipdb> b
# ipdb> b
# ipdb> type(b)
# <class 'list'>
# ipdb> b[0]
# *** The specified object '[0]' is not a function or was not found along sys.path.
# ipdb> y
# *** NameError: name 'y' is not defined
# ipdb> b
# ipdb> x
# *** NameError: name 'x' is not defined
# ipdb> q

# %%
#adacos_efficientnet_b3

# %%
#[adacos_efficientnet_b3.body._blocks[i] for i in range(26)]

# %%
# generate layer groups for discriminative layer training
# https://docs.fast.ai/basic_train.html#Discriminative-layer-training
learn.split((adacos_efficientnet_b3.body._conv_stem,
             #adacos_efficientnet_b3.body._blocks, # all blocks as a layer group
             *[adacos_efficientnet_b3.body._blocks[i] for i in range(26)], # put in each block in
             adacos_efficientnet_b3.body._conv_head,
             adacos_efficientnet_b3.head,
             adacos_efficientnet_b3.adacos
            ));

# %%
# we have 30 layer groups!
len(learn.lr_range(slice(1e-5,1e-3)))
# Out:
# 30

# %%
#learn.save('adacos_efficientnet_b3_pretrained_6d-input')

# %%
#learn.load('adacos_efficientnet_b3_pretrained_6d-input');

# %%
#learn.opt_func

# %%
#learn.to_fp16();

# %%
# Make Adam FP16 proof:
# https://forums.fast.ai/t/mixed-precision-training/29601/21
# https://discuss.pytorch.org/t/adam-half-precision-nans/1765
# https://vxlabs.com/2019/02/04/improving-fastais-mixed-precision-support-with-nvidias-automatic-mixed-precision/
#learn.opt_func = partial(learn.opt_func, eps=1e-4)
#learn.opt_func

### ADD CLIP PARAMETER TOO???

# %%
learn.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %%
#learn.layer_groups

# %%
def check_rg(model=learn.model):
    layer_rg = [(n, p.requires_grad) for n,p in model.named_parameters()]
    for i in range(len(layer_rg)):
        print(f'{layer_rg[i][0]}\t{layer_rg[i][1]}'.expandtabs(40))

# %%
# unfreeze network
learn.unfreeze()
#set_rg(learn.model.body, option=True)

# %%
check_rg() # check where trainable
# Out:
# body._conv_stem.weight                  True
# body._bn0.weight                        True
# body._bn0.bias                          True
# body._blocks.0._depthwise_conv.weight   True
# body._blocks.0._bn1.weight              True
# body._blocks.0._bn1.bias                True
# body._blocks.0._se_reduce.weight        True
# body._blocks.0._se_reduce.bias          True
# body._blocks.0._se_expand.weight        True
# body._blocks.0._se_expand.bias          True
# body._blocks.0._project_conv.weight     True
# body._blocks.0._bn2.weight              True
# body._blocks.0._bn2.bias                True
# body._blocks.1._depthwise_conv.weight   True
# body._blocks.1._bn1.weight              True
# body._blocks.1._bn1.bias                True
# body._blocks.1._se_reduce.weight        True
# body._blocks.1._se_reduce.bias          True
# body._blocks.1._se_expand.weight        True
# body._blocks.1._se_expand.bias          True
# body._blocks.1._project_conv.weight     True
# body._blocks.1._bn2.weight              True
# body._blocks.1._bn2.bias                True
# body._blocks.2._expand_conv.weight      True
# body._blocks.2._bn0.weight              True
# body._blocks.2._bn0.bias                True
# body._blocks.2._depthwise_conv.weight   True
# body._blocks.2._bn1.weight              True
# body._blocks.2._bn1.bias                True
# body._blocks.2._se_reduce.weight        True
# body._blocks.2._se_reduce.bias          True
# body._blocks.2._se_expand.weight        True
# body._blocks.2._se_expand.bias          True
# body._blocks.2._project_conv.weight     True
# body._blocks.2._bn2.weight              True
# body._blocks.2._bn2.bias                True
# body._blocks.3._expand_conv.weight      True
# body._blocks.3._bn0.weight              True
# body._blocks.3._bn0.bias                True
# body._blocks.3._depthwise_conv.weight   True
# body._blocks.3._bn1.weight              True
# body._blocks.3._bn1.bias                True
# body._blocks.3._se_reduce.weight        True
# body._blocks.3._se_reduce.bias          True
# body._blocks.3._se_expand.weight        True
# body._blocks.3._se_expand.bias          True
# body._blocks.3._project_conv.weight     True
# body._blocks.3._bn2.weight              True
# body._blocks.3._bn2.bias                True
# body._blocks.4._expand_conv.weight      True
# body._blocks.4._bn0.weight              True
# body._blocks.4._bn0.bias                True
# body._blocks.4._depthwise_conv.weight   True
# body._blocks.4._bn1.weight              True
# body._blocks.4._bn1.bias                True
# body._blocks.4._se_reduce.weight        True
# body._blocks.4._se_reduce.bias          True
# body._blocks.4._se_expand.weight        True
# body._blocks.4._se_expand.bias          True
# body._blocks.4._project_conv.weight     True
# body._blocks.4._bn2.weight              True
# body._blocks.4._bn2.bias                True
# body._blocks.5._expand_conv.weight      True
# body._blocks.5._bn0.weight              True
# body._blocks.5._bn0.bias                True
# body._blocks.5._depthwise_conv.weight   True
# body._blocks.5._bn1.weight              True
# body._blocks.5._bn1.bias                True
# body._blocks.5._se_reduce.weight        True
# body._blocks.5._se_reduce.bias          True
# body._blocks.5._se_expand.weight        True
# body._blocks.5._se_expand.bias          True
# body._blocks.5._project_conv.weight     True
# body._blocks.5._bn2.weight              True
# body._blocks.5._bn2.bias                True
# body._blocks.6._expand_conv.weight      True
# body._blocks.6._bn0.weight              True
# body._blocks.6._bn0.bias                True
# body._blocks.6._depthwise_conv.weight   True
# body._blocks.6._bn1.weight              True
# body._blocks.6._bn1.bias                True
# body._blocks.6._se_reduce.weight        True
# body._blocks.6._se_reduce.bias          True
# body._blocks.6._se_expand.weight        True
# body._blocks.6._se_expand.bias          True
# body._blocks.6._project_conv.weight     True
# body._blocks.6._bn2.weight              True
# body._blocks.6._bn2.bias                True
# body._blocks.7._expand_conv.weight      True
# body._blocks.7._bn0.weight              True
# body._blocks.7._bn0.bias                True
# body._blocks.7._depthwise_conv.weight   True
# body._blocks.7._bn1.weight              True
# body._blocks.7._bn1.bias                True
# body._blocks.7._se_reduce.weight        True
# body._blocks.7._se_reduce.bias          True
# body._blocks.7._se_expand.weight        True
# body._blocks.7._se_expand.bias          True
# body._blocks.7._project_conv.weight     True
# body._blocks.7._bn2.weight              True
# body._blocks.7._bn2.bias                True
# body._blocks.8._expand_conv.weight      True
# body._blocks.8._bn0.weight              True
# body._blocks.8._bn0.bias                True
# body._blocks.8._depthwise_conv.weight   True
# body._blocks.8._bn1.weight              True
# body._blocks.8._bn1.bias                True
# body._blocks.8._se_reduce.weight        True
# body._blocks.8._se_reduce.bias          True
# body._blocks.8._se_expand.weight        True
# body._blocks.8._se_expand.bias          True
# body._blocks.8._project_conv.weight     True
# body._blocks.8._bn2.weight              True
# body._blocks.8._bn2.bias                True
# body._blocks.9._expand_conv.weight      True
# body._blocks.9._bn0.weight              True
# body._blocks.9._bn0.bias                True
# body._blocks.9._depthwise_conv.weight   True
# body._blocks.9._bn1.weight              True
# body._blocks.9._bn1.bias                True
# body._blocks.9._se_reduce.weight        True
# body._blocks.9._se_reduce.bias          True
# body._blocks.9._se_expand.weight        True
# body._blocks.9._se_expand.bias          True
# body._blocks.9._project_conv.weight     True
# body._blocks.9._bn2.weight              True
# body._blocks.9._bn2.bias                True
# body._blocks.10._expand_conv.weight     True
# body._blocks.10._bn0.weight             True
# body._blocks.10._bn0.bias               True
# body._blocks.10._depthwise_conv.weight  True
# body._blocks.10._bn1.weight             True
# body._blocks.10._bn1.bias               True
# body._blocks.10._se_reduce.weight       True
# body._blocks.10._se_reduce.bias         True
# body._blocks.10._se_expand.weight       True
# body._blocks.10._se_expand.bias         True
# body._blocks.10._project_conv.weight    True
# body._blocks.10._bn2.weight             True
# body._blocks.10._bn2.bias               True
# body._blocks.11._expand_conv.weight     True
# body._blocks.11._bn0.weight             True
# body._blocks.11._bn0.bias               True
# body._blocks.11._depthwise_conv.weight  True
# body._blocks.11._bn1.weight             True
# body._blocks.11._bn1.bias               True
# body._blocks.11._se_reduce.weight       True
# body._blocks.11._se_reduce.bias         True
# body._blocks.11._se_expand.weight       True
# body._blocks.11._se_expand.bias         True
# body._blocks.11._project_conv.weight    True
# body._blocks.11._bn2.weight             True
# body._blocks.11._bn2.bias               True
# body._blocks.12._expand_conv.weight     True
# body._blocks.12._bn0.weight             True
# body._blocks.12._bn0.bias               True
# body._blocks.12._depthwise_conv.weight  True
# body._blocks.12._bn1.weight             True
# body._blocks.12._bn1.bias               True
# body._blocks.12._se_reduce.weight       True
# body._blocks.12._se_reduce.bias         True
# body._blocks.12._se_expand.weight       True
# body._blocks.12._se_expand.bias         True
# body._blocks.12._project_conv.weight    True
# body._blocks.12._bn2.weight             True
# body._blocks.12._bn2.bias               True
# body._blocks.13._expand_conv.weight     True
# body._blocks.13._bn0.weight             True
# body._blocks.13._bn0.bias               True
# body._blocks.13._depthwise_conv.weight  True
# body._blocks.13._bn1.weight             True
# body._blocks.13._bn1.bias               True
# body._blocks.13._se_reduce.weight       True
# body._blocks.13._se_reduce.bias         True
# body._blocks.13._se_expand.weight       True
# body._blocks.13._se_expand.bias         True
# body._blocks.13._project_conv.weight    True
# body._blocks.13._bn2.weight             True
# body._blocks.13._bn2.bias               True
# body._blocks.14._expand_conv.weight     True
# body._blocks.14._bn0.weight             True
# body._blocks.14._bn0.bias               True
# body._blocks.14._depthwise_conv.weight  True
# body._blocks.14._bn1.weight             True
# body._blocks.14._bn1.bias               True
# body._blocks.14._se_reduce.weight       True
# body._blocks.14._se_reduce.bias         True
# body._blocks.14._se_expand.weight       True
# body._blocks.14._se_expand.bias         True
# body._blocks.14._project_conv.weight    True
# body._blocks.14._bn2.weight             True
# body._blocks.14._bn2.bias               True
# body._blocks.15._expand_conv.weight     True
# body._blocks.15._bn0.weight             True
# body._blocks.15._bn0.bias               True
# body._blocks.15._depthwise_conv.weight  True
# body._blocks.15._bn1.weight             True
# body._blocks.15._bn1.bias               True
# body._blocks.15._se_reduce.weight       True
# body._blocks.15._se_reduce.bias         True
# body._blocks.15._se_expand.weight       True
# body._blocks.15._se_expand.bias         True
# body._blocks.15._project_conv.weight    True
# body._blocks.15._bn2.weight             True
# body._blocks.15._bn2.bias               True
# body._blocks.16._expand_conv.weight     True
# body._blocks.16._bn0.weight             True
# body._blocks.16._bn0.bias               True
# body._blocks.16._depthwise_conv.weight  True
# body._blocks.16._bn1.weight             True
# body._blocks.16._bn1.bias               True
# body._blocks.16._se_reduce.weight       True
# body._blocks.16._se_reduce.bias         True
# body._blocks.16._se_expand.weight       True
# body._blocks.16._se_expand.bias         True
# body._blocks.16._project_conv.weight    True
# body._blocks.16._bn2.weight             True
# body._blocks.16._bn2.bias               True
# body._blocks.17._expand_conv.weight     True
# body._blocks.17._bn0.weight             True
# body._blocks.17._bn0.bias               True
# body._blocks.17._depthwise_conv.weight  True
# body._blocks.17._bn1.weight             True
# body._blocks.17._bn1.bias               True
# body._blocks.17._se_reduce.weight       True
# body._blocks.17._se_reduce.bias         True
# body._blocks.17._se_expand.weight       True
# body._blocks.17._se_expand.bias         True
# body._blocks.17._project_conv.weight    True
# body._blocks.17._bn2.weight             True
# body._blocks.17._bn2.bias               True
# body._blocks.18._expand_conv.weight     True
# body._blocks.18._bn0.weight             True
# body._blocks.18._bn0.bias               True
# body._blocks.18._depthwise_conv.weight  True
# body._blocks.18._bn1.weight             True
# body._blocks.18._bn1.bias               True
# body._blocks.18._se_reduce.weight       True
# body._blocks.18._se_reduce.bias         True
# body._blocks.18._se_expand.weight       True
# body._blocks.18._se_expand.bias         True
# body._blocks.18._project_conv.weight    True
# body._blocks.18._bn2.weight             True
# body._blocks.18._bn2.bias               True
# body._blocks.19._expand_conv.weight     True
# body._blocks.19._bn0.weight             True
# body._blocks.19._bn0.bias               True
# body._blocks.19._depthwise_conv.weight  True
# body._blocks.19._bn1.weight             True
# body._blocks.19._bn1.bias               True
# body._blocks.19._se_reduce.weight       True
# body._blocks.19._se_reduce.bias         True
# body._blocks.19._se_expand.weight       True
# body._blocks.19._se_expand.bias         True
# body._blocks.19._project_conv.weight    True
# body._blocks.19._bn2.weight             True
# body._blocks.19._bn2.bias               True
# body._blocks.20._expand_conv.weight     True
# body._blocks.20._bn0.weight             True
# body._blocks.20._bn0.bias               True
# body._blocks.20._depthwise_conv.weight  True
# body._blocks.20._bn1.weight             True
# body._blocks.20._bn1.bias               True
# body._blocks.20._se_reduce.weight       True
# body._blocks.20._se_reduce.bias         True
# body._blocks.20._se_expand.weight       True
# body._blocks.20._se_expand.bias         True
# body._blocks.20._project_conv.weight    True
# body._blocks.20._bn2.weight             True
# body._blocks.20._bn2.bias               True
# body._blocks.21._expand_conv.weight     True
# body._blocks.21._bn0.weight             True
# body._blocks.21._bn0.bias               True
# body._blocks.21._depthwise_conv.weight  True
# body._blocks.21._bn1.weight             True
# body._blocks.21._bn1.bias               True
# body._blocks.21._se_reduce.weight       True
# body._blocks.21._se_reduce.bias         True
# body._blocks.21._se_expand.weight       True
# body._blocks.21._se_expand.bias         True
# body._blocks.21._project_conv.weight    True
# body._blocks.21._bn2.weight             True
# body._blocks.21._bn2.bias               True
# body._blocks.22._expand_conv.weight     True
# body._blocks.22._bn0.weight             True
# body._blocks.22._bn0.bias               True
# body._blocks.22._depthwise_conv.weight  True
# body._blocks.22._bn1.weight             True
# body._blocks.22._bn1.bias               True
# body._blocks.22._se_reduce.weight       True
# body._blocks.22._se_reduce.bias         True
# body._blocks.22._se_expand.weight       True
# body._blocks.22._se_expand.bias         True
# body._blocks.22._project_conv.weight    True
# body._blocks.22._bn2.weight             True
# body._blocks.22._bn2.bias               True
# body._blocks.23._expand_conv.weight     True
# body._blocks.23._bn0.weight             True
# body._blocks.23._bn0.bias               True
# body._blocks.23._depthwise_conv.weight  True
# body._blocks.23._bn1.weight             True
# body._blocks.23._bn1.bias               True
# body._blocks.23._se_reduce.weight       True
# body._blocks.23._se_reduce.bias         True
# body._blocks.23._se_expand.weight       True
# body._blocks.23._se_expand.bias         True
# body._blocks.23._project_conv.weight    True
# body._blocks.23._bn2.weight             True
# body._blocks.23._bn2.bias               True
# body._blocks.24._expand_conv.weight     True
# body._blocks.24._bn0.weight             True
# body._blocks.24._bn0.bias               True
# body._blocks.24._depthwise_conv.weight  True
# body._blocks.24._bn1.weight             True
# body._blocks.24._bn1.bias               True
# body._blocks.24._se_reduce.weight       True
# body._blocks.24._se_reduce.bias         True
# body._blocks.24._se_expand.weight       True
# body._blocks.24._se_expand.bias         True
# body._blocks.24._project_conv.weight    True
# body._blocks.24._bn2.weight             True
# body._blocks.24._bn2.bias               True
# body._blocks.25._expand_conv.weight     True
# body._blocks.25._bn0.weight             True
# body._blocks.25._bn0.bias               True
# body._blocks.25._depthwise_conv.weight  True
# body._blocks.25._bn1.weight             True
# body._blocks.25._bn1.bias               True
# body._blocks.25._se_reduce.weight       True
# body._blocks.25._se_reduce.bias         True
# body._blocks.25._se_expand.weight       True
# body._blocks.25._se_expand.bias         True
# body._blocks.25._project_conv.weight    True
# body._blocks.25._bn2.weight             True
# body._blocks.25._bn2.bias               True
# body._conv_head.weight                  True
# body._bn1.weight                        True
# body._bn1.bias                          True
# head.2.weight                           True
# head.2.bias                             True
# head.4.weight                           True
# head.4.bias                             True
# head.6.weight                           True
# head.6.bias                             True
# head.8.weight                           True
# head.8.bias                             True
# adacos.W                                True

# %%
#learn.summary()

# %% [markdown]
# ### Pretraining (input stage and head)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.31E-06
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(4, max_lr=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.033051</td>
#       <td>6.999560</td>
#       <td>0.001680</td>
#       <td>14:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.940973</td>
#       <td>6.909833</td>
#       <td>0.003489</td>
#       <td>14:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.872152</td>
#       <td>6.816776</td>
#       <td>0.004717</td>
#       <td>14:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.778571</td>
#       <td>6.782291</td>
#       <td>0.007237</td>
#       <td>14:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.recorder.plot_lr(show_moms=True)

# %%
learn.save('effnet/adacos_efficientnet_b3_e004_pretrain_inp-output_190803')

# %%
learn.load('effnet/adacos_efficientnet_b3_e004_pretrain_inp-output_190803')

# %%
# compare initialized input stage to pretrain input stage
show_input_stage_weights(new_weight)

# %%
show_input_stage_weights(learn.model.body._conv_stem.weight)

# %%
learn.unfreeze()
#set_rg(learn.model.body, option=True)

# %%
check_rg() # check where trainable
# Out:
# body._conv_stem.weight                  True
# body._bn0.weight                        True
# body._bn0.bias                          True
# body._blocks.0._depthwise_conv.weight   True
# body._blocks.0._bn1.weight              True
# body._blocks.0._bn1.bias                True
# body._blocks.0._se_reduce.weight        True
# body._blocks.0._se_reduce.bias          True
# body._blocks.0._se_expand.weight        True
# body._blocks.0._se_expand.bias          True
# body._blocks.0._project_conv.weight     True
# body._blocks.0._bn2.weight              True
# body._blocks.0._bn2.bias                True
# body._blocks.1._depthwise_conv.weight   True
# body._blocks.1._bn1.weight              True
# body._blocks.1._bn1.bias                True
# body._blocks.1._se_reduce.weight        True
# body._blocks.1._se_reduce.bias          True
# body._blocks.1._se_expand.weight        True
# body._blocks.1._se_expand.bias          True
# body._blocks.1._project_conv.weight     True
# body._blocks.1._bn2.weight              True
# body._blocks.1._bn2.bias                True
# body._blocks.2._expand_conv.weight      True
# body._blocks.2._bn0.weight              True
# body._blocks.2._bn0.bias                True
# body._blocks.2._depthwise_conv.weight   True
# body._blocks.2._bn1.weight              True
# body._blocks.2._bn1.bias                True
# body._blocks.2._se_reduce.weight        True
# body._blocks.2._se_reduce.bias          True
# body._blocks.2._se_expand.weight        True
# body._blocks.2._se_expand.bias          True
# body._blocks.2._project_conv.weight     True
# body._blocks.2._bn2.weight              True
# body._blocks.2._bn2.bias                True
# body._blocks.3._expand_conv.weight      True
# body._blocks.3._bn0.weight              True
# body._blocks.3._bn0.bias                True
# body._blocks.3._depthwise_conv.weight   True
# body._blocks.3._bn1.weight              True
# body._blocks.3._bn1.bias                True
# body._blocks.3._se_reduce.weight        True
# body._blocks.3._se_reduce.bias          True
# body._blocks.3._se_expand.weight        True
# body._blocks.3._se_expand.bias          True
# body._blocks.3._project_conv.weight     True
# body._blocks.3._bn2.weight              True
# body._blocks.3._bn2.bias                True
# body._blocks.4._expand_conv.weight      True
# body._blocks.4._bn0.weight              True
# body._blocks.4._bn0.bias                True
# body._blocks.4._depthwise_conv.weight   True
# body._blocks.4._bn1.weight              True
# body._blocks.4._bn1.bias                True
# body._blocks.4._se_reduce.weight        True
# body._blocks.4._se_reduce.bias          True
# body._blocks.4._se_expand.weight        True
# body._blocks.4._se_expand.bias          True
# body._blocks.4._project_conv.weight     True
# body._blocks.4._bn2.weight              True
# body._blocks.4._bn2.bias                True
# body._blocks.5._expand_conv.weight      True
# body._blocks.5._bn0.weight              True
# body._blocks.5._bn0.bias                True
# body._blocks.5._depthwise_conv.weight   True
# body._blocks.5._bn1.weight              True
# body._blocks.5._bn1.bias                True
# body._blocks.5._se_reduce.weight        True
# body._blocks.5._se_reduce.bias          True
# body._blocks.5._se_expand.weight        True
# body._blocks.5._se_expand.bias          True
# body._blocks.5._project_conv.weight     True
# body._blocks.5._bn2.weight              True
# body._blocks.5._bn2.bias                True
# body._blocks.6._expand_conv.weight      True
# body._blocks.6._bn0.weight              True
# body._blocks.6._bn0.bias                True
# body._blocks.6._depthwise_conv.weight   True
# body._blocks.6._bn1.weight              True
# body._blocks.6._bn1.bias                True
# body._blocks.6._se_reduce.weight        True
# body._blocks.6._se_reduce.bias          True
# body._blocks.6._se_expand.weight        True
# body._blocks.6._se_expand.bias          True
# body._blocks.6._project_conv.weight     True
# body._blocks.6._bn2.weight              True
# body._blocks.6._bn2.bias                True
# body._blocks.7._expand_conv.weight      True
# body._blocks.7._bn0.weight              True
# body._blocks.7._bn0.bias                True
# body._blocks.7._depthwise_conv.weight   True
# body._blocks.7._bn1.weight              True
# body._blocks.7._bn1.bias                True
# body._blocks.7._se_reduce.weight        True
# body._blocks.7._se_reduce.bias          True
# body._blocks.7._se_expand.weight        True
# body._blocks.7._se_expand.bias          True
# body._blocks.7._project_conv.weight     True
# body._blocks.7._bn2.weight              True
# body._blocks.7._bn2.bias                True
# body._blocks.8._expand_conv.weight      True
# body._blocks.8._bn0.weight              True
# body._blocks.8._bn0.bias                True
# body._blocks.8._depthwise_conv.weight   True
# body._blocks.8._bn1.weight              True
# body._blocks.8._bn1.bias                True
# body._blocks.8._se_reduce.weight        True
# body._blocks.8._se_reduce.bias          True
# body._blocks.8._se_expand.weight        True
# body._blocks.8._se_expand.bias          True
# body._blocks.8._project_conv.weight     True
# body._blocks.8._bn2.weight              True
# body._blocks.8._bn2.bias                True
# body._blocks.9._expand_conv.weight      True
# body._blocks.9._bn0.weight              True
# body._blocks.9._bn0.bias                True
# body._blocks.9._depthwise_conv.weight   True
# body._blocks.9._bn1.weight              True
# body._blocks.9._bn1.bias                True
# body._blocks.9._se_reduce.weight        True
# body._blocks.9._se_reduce.bias          True
# body._blocks.9._se_expand.weight        True
# body._blocks.9._se_expand.bias          True
# body._blocks.9._project_conv.weight     True
# body._blocks.9._bn2.weight              True
# body._blocks.9._bn2.bias                True
# body._blocks.10._expand_conv.weight     True
# body._blocks.10._bn0.weight             True
# body._blocks.10._bn0.bias               True
# body._blocks.10._depthwise_conv.weight  True
# body._blocks.10._bn1.weight             True
# body._blocks.10._bn1.bias               True
# body._blocks.10._se_reduce.weight       True
# body._blocks.10._se_reduce.bias         True
# body._blocks.10._se_expand.weight       True
# body._blocks.10._se_expand.bias         True
# body._blocks.10._project_conv.weight    True
# body._blocks.10._bn2.weight             True
# body._blocks.10._bn2.bias               True
# body._blocks.11._expand_conv.weight     True
# body._blocks.11._bn0.weight             True
# body._blocks.11._bn0.bias               True
# body._blocks.11._depthwise_conv.weight  True
# body._blocks.11._bn1.weight             True
# body._blocks.11._bn1.bias               True
# body._blocks.11._se_reduce.weight       True
# body._blocks.11._se_reduce.bias         True
# body._blocks.11._se_expand.weight       True
# body._blocks.11._se_expand.bias         True
# body._blocks.11._project_conv.weight    True
# body._blocks.11._bn2.weight             True
# body._blocks.11._bn2.bias               True
# body._blocks.12._expand_conv.weight     True
# body._blocks.12._bn0.weight             True
# body._blocks.12._bn0.bias               True
# body._blocks.12._depthwise_conv.weight  True
# body._blocks.12._bn1.weight             True
# body._blocks.12._bn1.bias               True
# body._blocks.12._se_reduce.weight       True
# body._blocks.12._se_reduce.bias         True
# body._blocks.12._se_expand.weight       True
# body._blocks.12._se_expand.bias         True
# body._blocks.12._project_conv.weight    True
# body._blocks.12._bn2.weight             True
# body._blocks.12._bn2.bias               True
# body._blocks.13._expand_conv.weight     True
# body._blocks.13._bn0.weight             True
# body._blocks.13._bn0.bias               True
# body._blocks.13._depthwise_conv.weight  True
# body._blocks.13._bn1.weight             True
# body._blocks.13._bn1.bias               True
# body._blocks.13._se_reduce.weight       True
# body._blocks.13._se_reduce.bias         True
# body._blocks.13._se_expand.weight       True
# body._blocks.13._se_expand.bias         True
# body._blocks.13._project_conv.weight    True
# body._blocks.13._bn2.weight             True
# body._blocks.13._bn2.bias               True
# body._blocks.14._expand_conv.weight     True
# body._blocks.14._bn0.weight             True
# body._blocks.14._bn0.bias               True
# body._blocks.14._depthwise_conv.weight  True
# body._blocks.14._bn1.weight             True
# body._blocks.14._bn1.bias               True
# body._blocks.14._se_reduce.weight       True
# body._blocks.14._se_reduce.bias         True
# body._blocks.14._se_expand.weight       True
# body._blocks.14._se_expand.bias         True
# body._blocks.14._project_conv.weight    True
# body._blocks.14._bn2.weight             True
# body._blocks.14._bn2.bias               True
# body._blocks.15._expand_conv.weight     True
# body._blocks.15._bn0.weight             True
# body._blocks.15._bn0.bias               True
# body._blocks.15._depthwise_conv.weight  True
# body._blocks.15._bn1.weight             True
# body._blocks.15._bn1.bias               True
# body._blocks.15._se_reduce.weight       True
# body._blocks.15._se_reduce.bias         True
# body._blocks.15._se_expand.weight       True
# body._blocks.15._se_expand.bias         True
# body._blocks.15._project_conv.weight    True
# body._blocks.15._bn2.weight             True
# body._blocks.15._bn2.bias               True
# body._blocks.16._expand_conv.weight     True
# body._blocks.16._bn0.weight             True
# body._blocks.16._bn0.bias               True
# body._blocks.16._depthwise_conv.weight  True
# body._blocks.16._bn1.weight             True
# body._blocks.16._bn1.bias               True
# body._blocks.16._se_reduce.weight       True
# body._blocks.16._se_reduce.bias         True
# body._blocks.16._se_expand.weight       True
# body._blocks.16._se_expand.bias         True
# body._blocks.16._project_conv.weight    True
# body._blocks.16._bn2.weight             True
# body._blocks.16._bn2.bias               True
# body._blocks.17._expand_conv.weight     True
# body._blocks.17._bn0.weight             True
# body._blocks.17._bn0.bias               True
# body._blocks.17._depthwise_conv.weight  True
# body._blocks.17._bn1.weight             True
# body._blocks.17._bn1.bias               True
# body._blocks.17._se_reduce.weight       True
# body._blocks.17._se_reduce.bias         True
# body._blocks.17._se_expand.weight       True
# body._blocks.17._se_expand.bias         True
# body._blocks.17._project_conv.weight    True
# body._blocks.17._bn2.weight             True
# body._blocks.17._bn2.bias               True
# body._blocks.18._expand_conv.weight     True
# body._blocks.18._bn0.weight             True
# body._blocks.18._bn0.bias               True
# body._blocks.18._depthwise_conv.weight  True
# body._blocks.18._bn1.weight             True
# body._blocks.18._bn1.bias               True
# body._blocks.18._se_reduce.weight       True
# body._blocks.18._se_reduce.bias         True
# body._blocks.18._se_expand.weight       True
# body._blocks.18._se_expand.bias         True
# body._blocks.18._project_conv.weight    True
# body._blocks.18._bn2.weight             True
# body._blocks.18._bn2.bias               True
# body._blocks.19._expand_conv.weight     True
# body._blocks.19._bn0.weight             True
# body._blocks.19._bn0.bias               True
# body._blocks.19._depthwise_conv.weight  True
# body._blocks.19._bn1.weight             True
# body._blocks.19._bn1.bias               True
# body._blocks.19._se_reduce.weight       True
# body._blocks.19._se_reduce.bias         True
# body._blocks.19._se_expand.weight       True
# body._blocks.19._se_expand.bias         True
# body._blocks.19._project_conv.weight    True
# body._blocks.19._bn2.weight             True
# body._blocks.19._bn2.bias               True
# body._blocks.20._expand_conv.weight     True
# body._blocks.20._bn0.weight             True
# body._blocks.20._bn0.bias               True
# body._blocks.20._depthwise_conv.weight  True
# body._blocks.20._bn1.weight             True
# body._blocks.20._bn1.bias               True
# body._blocks.20._se_reduce.weight       True
# body._blocks.20._se_reduce.bias         True
# body._blocks.20._se_expand.weight       True
# body._blocks.20._se_expand.bias         True
# body._blocks.20._project_conv.weight    True
# body._blocks.20._bn2.weight             True
# body._blocks.20._bn2.bias               True
# body._blocks.21._expand_conv.weight     True
# body._blocks.21._bn0.weight             True
# body._blocks.21._bn0.bias               True
# body._blocks.21._depthwise_conv.weight  True
# body._blocks.21._bn1.weight             True
# body._blocks.21._bn1.bias               True
# body._blocks.21._se_reduce.weight       True
# body._blocks.21._se_reduce.bias         True
# body._blocks.21._se_expand.weight       True
# body._blocks.21._se_expand.bias         True
# body._blocks.21._project_conv.weight    True
# body._blocks.21._bn2.weight             True
# body._blocks.21._bn2.bias               True
# body._blocks.22._expand_conv.weight     True
# body._blocks.22._bn0.weight             True
# body._blocks.22._bn0.bias               True
# body._blocks.22._depthwise_conv.weight  True
# body._blocks.22._bn1.weight             True
# body._blocks.22._bn1.bias               True
# body._blocks.22._se_reduce.weight       True
# body._blocks.22._se_reduce.bias         True
# body._blocks.22._se_expand.weight       True
# body._blocks.22._se_expand.bias         True
# body._blocks.22._project_conv.weight    True
# body._blocks.22._bn2.weight             True
# body._blocks.22._bn2.bias               True
# body._blocks.23._expand_conv.weight     True
# body._blocks.23._bn0.weight             True
# body._blocks.23._bn0.bias               True
# body._blocks.23._depthwise_conv.weight  True
# body._blocks.23._bn1.weight             True
# body._blocks.23._bn1.bias               True
# body._blocks.23._se_reduce.weight       True
# body._blocks.23._se_reduce.bias         True
# body._blocks.23._se_expand.weight       True
# body._blocks.23._se_expand.bias         True
# body._blocks.23._project_conv.weight    True
# body._blocks.23._bn2.weight             True
# body._blocks.23._bn2.bias               True
# body._blocks.24._expand_conv.weight     True
# body._blocks.24._bn0.weight             True
# body._blocks.24._bn0.bias               True
# body._blocks.24._depthwise_conv.weight  True
# body._blocks.24._bn1.weight             True
# body._blocks.24._bn1.bias               True
# body._blocks.24._se_reduce.weight       True
# body._blocks.24._se_reduce.bias         True
# body._blocks.24._se_expand.weight       True
# body._blocks.24._se_expand.bias         True
# body._blocks.24._project_conv.weight    True
# body._blocks.24._bn2.weight             True
# body._blocks.24._bn2.bias               True
# body._blocks.25._expand_conv.weight     True
# body._blocks.25._bn0.weight             True
# body._blocks.25._bn0.bias               True
# body._blocks.25._depthwise_conv.weight  True
# body._blocks.25._bn1.weight             True
# body._blocks.25._bn1.bias               True
# body._blocks.25._se_reduce.weight       True
# body._blocks.25._se_reduce.bias         True
# body._blocks.25._se_expand.weight       True
# body._blocks.25._se_expand.bias         True
# body._blocks.25._project_conv.weight    True
# body._blocks.25._bn2.weight             True
# body._blocks.25._bn2.bias               True
# body._conv_head.weight                  True
# body._bn1.weight                        True
# body._bn1.bias                          True
# head.2.weight                           True
# head.2.bias                             True
# head.4.weight                           True
# head.4.bias                             True
# head.6.weight                           True
# head.6.bias                             True
# head.8.weight                           True
# head.8.bias                             True
# adacos.W                                True

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.75E-06
# Min loss divided by 10: 6.31E-08

# %%
learn.lr_range(slice(1e-6,1e-3))
# Out:
# array([1.000000e-06, 1.268961e-06, 1.610262e-06, 2.043360e-06, 2.592944e-06, 3.290345e-06, 4.175319e-06, 5.298317e-06,
#        6.723358e-06, 8.531679e-06, 1.082637e-05, 1.373824e-05, 1.743329e-05, 2.212216e-05, 2.807216e-05, 3.562248e-05,
#        4.520354e-05, 5.736153e-05, 7.278954e-05, 9.236709e-05, 1.172102e-04, 1.487352e-04, 1.887392e-04, 2.395027e-04,
#        3.039195e-04, 3.856620e-04, 4.893901e-04, 6.210169e-04, 7.880463e-04, 1.000000e-03])

# %%
lrs = learn.lr_range(slice(1e-6,1e-3))

# %%
learn.fit_one_cycle(8, max_lr=lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.682956</td>
#       <td>6.715293</td>
#       <td>0.008723</td>
#       <td>17:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.629867</td>
#       <td>6.688751</td>
#       <td>0.010016</td>
#       <td>17:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.570286</td>
#       <td>6.551707</td>
#       <td>0.015249</td>
#       <td>17:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.446850</td>
#       <td>6.459234</td>
#       <td>0.018028</td>
#       <td>17:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.357745</td>
#       <td>6.419240</td>
#       <td>0.021323</td>
#       <td>17:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.282457</td>
#       <td>6.276729</td>
#       <td>0.027397</td>
#       <td>17:33</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.219238</td>
#       <td>6.270132</td>
#       <td>0.029659</td>
#       <td>17:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6.232030</td>
#       <td>6.252248</td>
#       <td>0.031533</td>
#       <td>17:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.save('effnet/adacos_efficientnet_b3_e012_190803')

# %%
learn.load('effnet/adacos_efficientnet_b3_e012_190803');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.31E-06
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(8, max_lr=lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.161398</td>
#       <td>6.272714</td>
#       <td>0.030951</td>
#       <td>17:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.225909</td>
#       <td>6.286244</td>
#       <td>0.025911</td>
#       <td>17:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.180725</td>
#       <td>6.228970</td>
#       <td>0.030370</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.094318</td>
#       <td>6.140015</td>
#       <td>0.036960</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.003651</td>
#       <td>6.064408</td>
#       <td>0.041677</td>
#       <td>17:35</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.910089</td>
#       <td>5.997221</td>
#       <td>0.046847</td>
#       <td>17:35</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.874354</td>
#       <td>5.979558</td>
#       <td>0.050078</td>
#       <td>17:35</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.868858</td>
#       <td>5.964226</td>
#       <td>0.052210</td>
#       <td>17:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
#learn.recorder.plot_lr()

# %%
learn.save('effnet/adacos_efficientnet_b3_e020_190803')

# %%
learn.load('effnet/adacos_efficientnet_b3_e020_190803');

# %%
# compare initialized input stage to pretrain input stage
show_input_stage_weights(new_weight)

# %%
show_input_stage_weights(learn.model.body._conv_stem.weight)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.32E-06
# Min loss divided by 10: 5.75E-07

# %%
learn.fit_one_cycle(20, max_lr=lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.883934</td>
#       <td>5.952822</td>
#       <td>0.049431</td>
#       <td>17:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.886474</td>
#       <td>5.952761</td>
#       <td>0.049561</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.841702</td>
#       <td>5.936434</td>
#       <td>0.048721</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.876679</td>
#       <td>5.903089</td>
#       <td>0.050530</td>
#       <td>17:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.922779</td>
#       <td>5.909384</td>
#       <td>0.048398</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.839325</td>
#       <td>5.873977</td>
#       <td>0.049754</td>
#       <td>17:38</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.726617</td>
#       <td>5.825124</td>
#       <td>0.053308</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.660325</td>
#       <td>5.793094</td>
#       <td>0.061321</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>5.614190</td>
#       <td>5.746886</td>
#       <td>0.065779</td>
#       <td>17:36</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>5.560707</td>
#       <td>5.723673</td>
#       <td>0.068558</td>
#       <td>17:37</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.548503</td>
#       <td>5.684380</td>
#       <td>0.070496</td>
#       <td>17:38</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>5.512535</td>
#       <td>5.631205</td>
#       <td>0.075859</td>
#       <td>17:37</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>5.443708</td>
#       <td>5.603600</td>
#       <td>0.079349</td>
#       <td>17:38</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>5
# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
learn.recorder.plot_lr()

# %%
learn.save('effnet/adacos_efficientnet_b3_e080CM125CO075_190808')

# %%
learn.load('effnet/adacos_efficientnet_b3_e080CM125CO075_190808');

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 7.59E-07
# Min loss divided by 10: 4.37E-06

# %%
mv adacos_efficientnet_b3_e080CM125CO030-075_190807_best.pth adacos_efficientnet_b3_e080CM125CO030-075_190808_best.pth

# %% [markdown]
# ### Custom Blend CutMix

# %%
kwargs = {
    'size': .05, 
    'alpha': .2,
    'blend_type': 'zero', 
}

# %%
learn.blend(**kwargs);

# %%
learn.fit_one_cycle(4, 1e-3)

# %%
# %debug

# %%
# Define transform function
tfm_fn = partial(blend, blend_type='cut', same_size=False)

#Define schedule parameters
sch_param=['size', 'fixed_proba']
sch_val = [(.05, 2), .2 ]  # You can also enter a list of tuples
sch_iter = [(0., .3), (0., .7)]  # And a tuple with start and end iteration percentage
sch_func = [annealing_cos, partial(cosine_annealing, pct_start=.3)] # options: None = annealing_linear, annealing_cos, cosine_annealing
plot = True
test = True  # if True this will stop training in the first mini-batch
sch_tfm_cb = partial(TfmScheduler, tfm_fn=tfm_fn, sch_param=sch_param, sch_val=sch_val, 
                      sch_iter=sch_iter, sch_func=sch_func, plot=plot, test=test)
learn.callback_fns.append(sch_tfm_cb)

# %% [markdown]
# # Submission

# %% [markdown]
# ## Classifcation

# %%
learn.load('resnet50/adacos_se_xresnet50c_val-split-v2_128e040-256e106CMe110_20190729');

# %%
# get prediction of test dataset
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
# check length
len(preds)
# Out:
# 39794

# %%
# get the categories
preds_cat = preds.argmax(dim=-1)

# %%
# get the names
preds_names = learn.data.test_ds.x.items

# %%
# without site
#preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3][:3] for x in preds_names]

# with site
preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3] for x in preds_names]

# %%
df_preds = pd.DataFrame({'id_code_site': preds_names, 'sirna': preds_cat})

# %%
# get id_code without site
df_preds['id_code'] = df_preds['id_code_site'].apply(lambda x: x[:-3])

# %%
# get row indices with the same/not the same the prediction for both sites
idx = [] # indices with the same prediction
idx_notsame = [] # indices with not the same prediction
for i, r in enumerate(df_preds.sort_values('id_code').iterrows()):
    if i % 2:
        # distance from row 2 is 
        if pred == r[1]['sirna']:
            idx.append(r[0])
        else:
            #idx.append(r[0]) # always append idx until we come up with something better
            idx.append(idx_row_before)
            idx_notsame.append(idx_row_before) # get the first rows of the pairs that are not the same
    else:
        # save dist from row 1 for comparison in next iteration
        pred = r[1]['sirna']
        idx_row_before = r[0]

# %%
len(idx), len(idx_notsame)
# Out:
# (19897, 13319)

# %%
idx[:5]
# Out:
# [19897, 1, 2, 3, 4]

# %%
df_preds.sort_values('id_code').head(10)
# Out:
#             id_code_site  sirna         id_code
# 0      HEPG2-08_1_B03_s1    855  HEPG2-08_1_B03
# 19897  HEPG2-08_1_B03_s2    855  HEPG2-08_1_B03
# 19898  HEPG2-08_1_B04_s2    192  HEPG2-08_1_B04
# 1      HEPG2-08_1_B04_s1    192  HEPG2-08_1_B04
# 2      HEPG2-08_1_B05_s1    926  HEPG2-08_1_B05
# 19899  HEPG2-08_1_B05_s2    277  HEPG2-08_1_B05
# 3      HEPG2-08_1_B06_s1    640  HEPG2-08_1_B06
# 19900  HEPG2-08_1_B06_s2    650  HEPG2-08_1_B06
# 4      HEPG2-08_1_B07_s1    565  HEPG2-08_1_B07
# 19901  HEPG2-08_1_B07_s2    532  HEPG2-08_1_B07

# %%
#df_preds.loc[idx,['id_code','sirna']]

# %%
# 'effnet/adacos_efficientnet_b3_e080CM112_190805'
model = 'metriclearn_efficientnet_b3_e080CM112_190805'

# %%
df_preds.loc[idx,['id_code','sirna']].to_csv('sub/'+model+'.csv.gz', index=False, compression='gzip')

# %%
# !kaggle competitions submit -c recursion-cellular-image-classification -f sub/{model}.csv.gz -m "{model}"
# Out:
# 100%|██████████████████████████████████████| 83.2k/83.2k [00:04<00:00, 20.9kB/s]
# Successfully submitted to Recursion Cellular Image Classification

# %% [markdown]
# ## Cosinus similarity

# %% [markdown]
# ### Full single features

# %%
# https://github.com/ducha-aiki/whale-identification-2018/blob/master/reproduce_problems.ipynb
# And for test-time augmentation I used following random solution: switch train and val transforms

# %%
# extended tfms
tfms = get_transforms(do_flip=True, flip_vert=True, 
                      max_rotate=90.0, max_zoom=1.1, 
                      max_lighting=0.2, max_warp=0.2, 
                      p_affine=0.75, p_lighting=0.75, 
                      xtra_tfms=[color_augmentation()])

# crop_pad: https://forums.fast.ai/t/misc-issues/35386/10

# %%
# extended tfms w/o color_augmentation !!!
tfms = get_transforms(do_flip=True, flip_vert=True, 
                      max_rotate=90.0, max_zoom=1.1, 
                      max_lighting=0.2, max_warp=0.2, 
                      p_affine=0.75, p_lighting=0.75)

# %%
# sz, bs = 300, 8*2
sz, bs = 512, 8*3

# %%
# VALID SPLIT (incl. tfms)
data = (ImageList6D.from_df(df_train, path='train')
        .split_from_df(col=-1) # split_by_rand_pct()
        .label_from_df(cols=-3)
        .add_test(ImageList6D.from_df(df_test, path='test'))
        .transform(tfms)#, size=sz) # remove size so we get the crop size!
        .databunch(bs=bs))

# %%
# Batch-wise normalization should be enough because the deviation is max. 6%
# see "rcic_v10_inspect_image_data.ipynb" for analysis.
#data.normalize() # https://docs.fast.ai/vision.data.html#ImageDataBunch.batch_stats

data.normalize([tensor([0.0456, 0.0702, 0.0447, 0.0468, 0.0407, 0.0399]),
                tensor([0.0644, 0.0733, 0.0536, 0.0633, 0.0555, 0.0392])]);

# efficientnet stats https://github.com/lukemelas/EfficientNet-PyTorch#example-classification
#data.normalize(([0.485, 0.456, 0.406, 0.485, 0.456, 0.406],
#               [0.229, 0.224, 0.225, 0.229, 0.224, 0.225]))

# mean of mean, and mean of std from rcic_v10_inspect_image_data.ipynb
#data.normalize()

# %%
#data.train_dl.dl.batch_sampler.sampler = torch.utils.data.SequentialSampler(data.train_ds)
#data.train_dl.dl.batch_sampler.drop_last = False
#
#data.valid_dl.dl.batch_sampler.sampler = torch.utils.data.SequentialSampler(data.valid_ds)
#data.valid_dl.dl.batch_sampler.drop_last = False
#
## DOES WORK TOO FOR TEST DL ??? ??? (Or do we need to set the test dataset to the valid dataset?)
#data.test_dl.dl.batch_sampler.sampler = torch.utils.data.SequentialSampler(data.test_ds)
#data.test_dl.dl.batch_sampler.drop_last = False

# %%
learn = Learner(data, adacos_efficientnet_b3)

# %%
learn.load('effnet/adacos_efficientnet_b3_e080CM185-230_190807_best')

# %%
def get_feats(model, dataloader, cycles=1):
    feats = []
    targs = []
    model.eval()
    with torch.no_grad():
        for i in range(cycles): # for TTA
            for xb, yb in dataloader:
                body_out = model.body(xb)
                head_out = model.head(body_out)
                feats.append(head_out.cpu())
                targs.append(yb.cpu())
    return feats, targs

# %% [markdown]
# #### Train

# %%
feats, targs = get_feats(learn.model, learn.data.train_dl)#, cycles=3)

# %%
len(feats), len(targs)
# Out:
# (7194, 7194)

# %%
# total images: 89*320
learn.data.batch_size * len(learn.data.train_dl)
# Out:
# 57552

# %%
#len(learn.data.train_dl), len(learn.data.valid_dl), len(learn.data.test_dl)

# %%
feats = torch.cat(feats, dim=0)
targs = torch.cat(targs, dim=0)

# %%
feats.shape, targs.shape
# Out:
# (torch.Size([57552, 512]), torch.Size([57552]))

# %%
np.save('pred/feats_train.npy', feats)
np.save('pred/targs_train.npy', targs)

# %% [markdown]
# #### Valid

# %%
feats, targs = get_feats(learn.model, learn.data.valid_dl)

# %%
len(feats), len(targs)
# Out:
# (1935, 1935)

# %%
feats = torch.cat(feats, dim=0)
targs = torch.cat(targs, dim=0)

# %%
feats.shape, feats.shape, targs.shape
# Out:
# (torch.Size([15476, 512]), torch.Size([15476, 512]), torch.Size([15476]))

# %%
np.save('pred/feats_valid.npy', feats)
np.save('pred/targs_valid.npy', targs)

# %% [markdown]
# #### Test

# %%
feats, targs = get_feats(learn.model, learn.data.test_dl)

# %%
del targs

# %%
len(feats)
# Out:
# 4975

# %%
feats = torch.cat(feats, dim=0)

# %%
feats.shape
# Out:
# torch.Size([39794, 512])

# %%
np.save('pred/feats_test.npy', feats)

# %% [markdown]
# ### Multi-crop features

# %%
# https://github.com/ducha-aiki/whale-identification-2018/blob/master/reproduce_problems.ipynb
# And for test-time augmentation I used following random solution: switch train and val transforms

# %%
df_train['test'] = 0
df_train['path'] = 'train/'+df_train['path']

# %%
df_train.head()
# Out:
#                            path experiment  sirna          multi  valid  test
# 0  train/HEPG2-01/Plate1/B03_s1   HEPG2-01    513   HEPG2-01 513      0     0
# 1  train/HEPG2-01/Plate1/B04_s1   HEPG2-01    840   HEPG2-01 840      0     0
# 2  train/HEPG2-01/Plate1/B05_s1   HEPG2-01   1020  HEPG2-01 1020      0     0
# 3  train/HEPG2-01/Plate1/B06_s1   HEPG2-01    254   HEPG2-01 254      0     0
# 4  train/HEPG2-01/Plate1/B07_s1   HEPG2-01    144   HEPG2-01 144      0     0

# %%
# add dummy columns for test dataset
df_test['path'] = 'test/'+df_test['path']
df_test['test'] = 1
df_test['sirna'] = 1

# %%
df_test.head()
# Out:
#                           path experiment  test  sirna
# 0  test/HEPG2-08/Plate1/B03_s1   HEPG2-08     1      1
# 1  test/HEPG2-08/Plate1/B04_s1   HEPG2-08     1      1
# 2  test/HEPG2-08/Plate1/B05_s1   HEPG2-08     1      1
# 3  test/HEPG2-08/Plate1/B06_s1   HEPG2-08     1      1
# 4  test/HEPG2-08/Plate1/B07_s1   HEPG2-08     1      1

# %%
df_train_test = pd.concat((df_train, df_test), axis=0, sort=False)

# %%
df_train_test.tail()
# Out:
#                              path experiment  sirna multi  valid  test
# 19892  test/U2OS-05/Plate4/O19_s2    U2OS-05      1   NaN    NaN     1
# 19893  test/U2OS-05/Plate4/O20_s2    U2OS-05      1   NaN    NaN     1
# 19894  test/U2OS-05/Plate4/O21_s2    U2OS-05      1   NaN    NaN     1
# 19895  test/U2OS-05/Plate4/O22_s2    U2OS-05      1   NaN    NaN     1
# 19896  test/U2OS-05/Plate4/O23_s2    U2OS-05      1   NaN    NaN     1

# %%
# reload for train and valid ds
df_train = pd.read_csv('full_train_dataset_valid-split-ex_v2_20190727.csv', index_col=0)
df_test = pd.read_csv('full_test_dataset_v2_20190727.csv', index_col=0)

# %%
# test tfms switching for test ds
#tfms_switched = (tfms[1], tfms[0])
#
#data = (ImageList6D.from_df(df_train_test, path='.')
#                .split_from_df(col=-1)
#                .label_from_df(cols=-4)
#                .transform(tfms_switched)#, size=sz) # remove size so we get the crop size!
#                .databunch(bs=bs))

# %%
#data.train_ds[0][0]

# %%
#data.valid_ds[0][0]

# %%
def get_dataset(row_pct, col_pct, is_test=False):
    # extended tfms
    tfms = get_transforms(do_flip=True, flip_vert=True, 
                          max_rotate=90.0, max_zoom=1.1, 
                          max_lighting=0.2, max_warp=0.2, 
                          p_affine=0.75, p_lighting=0.75, 
                          xtra_tfms=[color_augmentation()])
    
    # change "crop_pad" from get_transforms to "crop"
    tfms[0][0] = crop(size=sz, row_pct=row_pct, col_pct=col_pct)
    tfms[1][0] = crop(size=sz, row_pct=row_pct, col_pct=col_pct)
    
    # VALID SPLIT (incl. tfms)
    if is_test:
        #switch train with valid (= test) tfms!
        tfms_switched = (tfms[1], tfms[0])
        
        data = (ImageList6D.from_df(df_train_test, path='.')
                .split_from_df(col=-1)
                .label_from_df(cols=-4)
                .transform(tfms_switched)#, size=sz) # remove size so we get the crop size!
                .databunch(bs=bs))
    else:
        data = (ImageList6D.from_df(df_train, path='train')
                .split_from_df(col=-1) # split_by_rand_pct()
                .label_from_df(cols=-3)
                #.add_test(ImageList6D.from_df(df_test, path='test'))
                .transform(tfms)#, size=sz) # remove size so we get the crop size!
                .databunch(bs=bs))
    
    data.normalize([tensor([0.0456, 0.0702, 0.0447, 0.0468, 0.0407, 0.0399]),
                    tensor([0.0644, 0.0733, 0.0536, 0.0633, 0.0555, 0.0392])]);
    
    return data

# %%
def get_feats(model, dataloader, cycles=1):
    feats = []
    targs = []
    model.eval()
    with torch.no_grad():
        for i in range(cycles): # for TTA
            for xb, yb in dataloader:
                body_out = model.body(xb)
                head_out = model.head(body_out)
                feats.append(head_out.cpu())
                targs.append(yb.cpu())
                
    feats = torch.cat(feats, dim=0)
    targs = torch.cat(targs, dim=0)
    
    return feats, targs

# %%
def save_feats(feats, targs, crop, ds='train'):
    np.save(f'pred/feats_{ds}_crop{crop}.npy', feats)
    np.save(f'pred/targs_{ds}_crop{crop}.npy', targs)

# %%
#https://docs.fast.ai/vision.transform.html#_crop
crop_pos = [[0.,0.], [0.,1.],[0.5,0.5],[1.,0.], [1.,1.]]

# %%
# get random crop pos
i = 2
crop_pos = [[uniform(0,1), uniform(0,1)] for i in range(2)]

# %%
crop_pos
# Out:
# [[0.5533107157335633, 0.30835987173647583],
#  [0.6173760331497686, 0.0039496017383227056]]

# %%
# get the last three crop positions:
crop_pos = [[0.5,0.5],[1.,0.], [1.,1.]]

# %%
def get_crop_feats(model=learn.model, cycles=1, crop_pos=crop_pos):
    
    for i, (row_pct, col_pct) in enumerate(crop_pos):
        
        print('== crop#:', i,' of', len(crop_pos), '==')
        print('row_pct:', row_pct,', col_pct:', col_pct)
    
        data = get_dataset(row_pct, col_pct)
        
        # train
        print('= Start train dataset =')
        feats, targs = get_feats(model, data.train_dl)
        save_feats(feats, targs, i, ds='train')
        print('feats:', feats.shape,' targs:', targs.shape)
        print('- Finish train dataset -')
        
        # valid
        print('= Start valid dataset =')
        feats, targs = get_feats(model, data.valid_dl)
        save_feats(feats, targs, i, ds='valid')
        print('feats:', feats.shape,' targs:', targs.shape)
        print('- Finish valid dataset -')
        
        # get test ds as valid ds for TTA
        data = get_dataset(row_pct, col_pct, is_test=True)
        
        # test
        print('= Start test dataset =')
        feats, targs = get_feats(model, data.valid_dl)
        save_feats(feats, targs, i, ds='test')
        print('feats:', feats.shape,' targs:', targs.shape)
        print('- Finish test dataset -')

# %%
learn = Learner(data, adacos_efficientnet_b3)

# %%
learn.load('effnet/adacos_efficientnet_b3_e080CM112_190805');

# %%
get_crop_feats()
# Out:
# == crop#: 0  of 5 ==
# row_pct: 0.0 , col_pct: 0.0
# = Start train dataset =
# feats: torch.Size([57552, 512])  targs: torch.Size([57552])
# - Finish train dataset -
# = Start valid dataset =
# feats: torch.Size([15476, 512])  targs: torch.Size([15476])
# - Finish train dataset -
# = Start test dataset =
# feats: torch.Size([39794, 512])  targs: torch.Size([39794])
# - Finish test dataset -
# == crop#: 1  of 5 ==
# row_pct: 0.0 , col_pct: 1.0
# = Start train dataset =
# feats: torch.Size([57552, 512])  targs: torch.Size([57552])
# - Finish train dataset -
# = Start valid dataset =
# feats: torch.Size([15476, 512])  targs: torch.Size([15476])
# - Finish train dataset -
# = Start test dataset =
# feats: torch.Size([39794, 512])  targs: torch.Size([39794])
# - Finish test dataset -
# == crop#: 2  of 5 ==
# row_pct: 0.5 , col_pct: 0.5
# = Start train dataset =
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-340-5c24c1450f62> in <module>
# ----> 1 get_crop_feats()
#
# <ipython-input-337-295239eddd01> in get_crop_feats(model, cycles, crop_pos)
#      10         # train
#      11         print('= Start train dataset =')
# ---> 12         feats, targs = get_feats(model, data.train_dl)
#      13         save_feats(feats, targs, i, ds='train')
#      14         print('feats:', feats.shape,' targs:', targs.shape)
#
# <ipython-input-305-ed78869ee2a5> in get_feats(model, dataloader, cycles)
#       5     with torch.no_grad():
#       6         for i in range(cycles): # for TTA
# ----> 7             for xb, yb in dataloader:
#       8                 body_out = model.body(xb)
#       9                 head_out = model.head(body_out)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     574         while True:
#     575             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 576             idx, batch = self._get_batch()
#     577             self.batches_outstanding -= 1
#     578             if idx != self.rcvd_idx:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     541         elif self.pin_memory:
#     542             while self.pin_memory_thread.is_alive():
# --> 543                 success, data = self._try_get_batch()
#     544                 if success:
#     545                     return data
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_batch(self, timeout)
#     509         #   (bool: whether successfully get data, any: data if successful else None)
#     510         try:
# --> 511             data = self.data_queue.get(timeout=timeout)
#     512             return (True, data)
#     513         except Exception as e:
#
# ~/anaconda3/envs/fastai/lib/python3.6/queue.py in get(self, block, timeout)
#     171                     if remaining <= 0.0:
#     172                         raise Empty
# --> 173                     self.not_empty.wait(remaining)
#     174             item = self._get()
#     175             self.not_full.notify()
#
# ~/anaconda3/envs/fastai/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
#data = (ImageList6D.from_df(df_train_test, path='.')
#        .split_from_df(col=-1)
#        .label_from_df(cols=-4)
#        .transform(tfms_switched)#, size=sz) # remove size so we get the crop size!
#        .databunch(bs=bs))

# %% [markdown]
# ### Submission

# %%
# get the names
preds_names = learn.data.test_ds.x.items

# %%
# without site
#preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3][:3] for x in preds_names]

# with site
preds_names = [x.split('/')[1]+'_'+x.split('/')[2][-1]+'_'+x.split('/')[3] for x in preds_names]

# %%
preds_test = np.load('pred/preds_test.npy')
dist_test = np.load('pred/dist_test.npy')

# %%
len(preds_names), len(preds_test), len(dist_test)
# Out:
# (39794, 39794, 39794)

# %%
#preds_test

# %%
#dist_test

# %%
df_preds = pd.DataFrame({'id_code_site': preds_names, 'sirna': preds_test, 'cossim': dist_test})

# %%
# get id_code without site
df_preds['id_code'] = df_preds['id_code_site'].apply(lambda x: x[:-3])

# %%
# get row indices with highest cosine similiarity
idx = []
for i, r in enumerate(df_preds.sort_values('id_code').iterrows()):
    #print(r)
    #print('i: ',i)
    #print('idx: ',r[0])
    #print(r[1]['cossim'])
    if i % 2:
        # distance from row 2 is 
        if dist < r[1]['cossim']:
            idx.append(r[0])
        else:
            idx.append(idx_row_before)
    else:
        # save dist from row 1 for comparison in next iteration
        dist = r[1]['cossim']
        idx_row_before = r[0]

# %%
idx[:5]
# Out:
# [0, 19898, 19899, 19900, 4]

# %%
df_preds.sort_values('id_code').head(10)
# Out:
#             id_code_site  sirna    cossim         id_code
# 0      HEPG2-08_1_B03_s1    381  0.732310  HEPG2-08_1_B03
# 19897  HEPG2-08_1_B03_s2    381  0.571654  HEPG2-08_1_B03
# 19898  HEPG2-08_1_B04_s2    265  0.595857  HEPG2-08_1_B04
# 1      HEPG2-08_1_B04_s1    265  0.526492  HEPG2-08_1_B04
# 2      HEPG2-08_1_B05_s1    123  0.538773  HEPG2-08_1_B05
# 19899  HEPG2-08_1_B05_s2    277  0.700385  HEPG2-08_1_B05
# 3      HEPG2-08_1_B06_s1   1032  0.579255  HEPG2-08_1_B06
# 19900  HEPG2-08_1_B06_s2   1075  0.695978  HEPG2-08_1_B06
# 4      HEPG2-08_1_B07_s1    585  0.691013  HEPG2-08_1_B07
# 19901  HEPG2-08_1_B07_s2    430  0.594106  HEPG2-08_1_B07

# %%
#df_preds.loc[idx,['id_code','sirna']]

# %%
# 'effnet/adacos_efficientnet_b3_e080CM185-230_190807_best'
model = 'metriclearn_efficientnet_b3_e080CM185-230_190807_best_512px-no-col-aug'

# %%
df_preds.loc[idx,['id_code','sirna']].to_csv('sub/'+model+'.csv.gz', index=False, compression='gzip')

# %%
# !kaggle competitions submit -c recursion-cellular-image-classification -f sub/{model}.csv.gz -m "{model}"
# Out:
# 100%|██████████████████████████████████████| 83.9k/83.9k [00:04<00:00, 20.9kB/s]
# Successfully submitted to Recursion Cellular Image Classification

# %% [markdown]
# # Error analysis

# %%
preds_correct = np.load('preds_valid_correct.npy')

# %%
df_erros = pd.DataFrame({'id_code': preds_names, 'correct': preds_test})

# %%
df_erros[df_errors['correct'] == False]

# %%
# ERROR ANALYSIS !!!
